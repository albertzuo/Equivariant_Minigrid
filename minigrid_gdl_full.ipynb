# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.vec_env import VecNormalize
import torch
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

from envs.custom_fourrooms import FourRoomsEnv17, FourRoomsEnv15, FourRoomsEnv13, FourRoomsEnv11, FourRoomsEnv09
from vis.visualization import create_animation, capture_frames_sb3, capture_side_by_side_comparison
from wrappers import BaseWrapper, RandomRotateWrapper, Rotate90Wrapper, Rotate180Wrapper, Rotate270Wrapper
from models.features_extractor import MinigridFeaturesExtractor, SmallKernelC4EquivariantCNN, MostlyC4EquivariantCNN

from tensorboard import notebook

# %%
ENV_NAME = FourRoomsEnv09#'MiniGrid-FourRooms-v0'

TIMESTEPS = 1e6

NUM_EVAL_EPISODES = 10
RENDER_EVALUATION = True

TENSORBOARD_LOG_DIR = "./tensorboard_logs/"

SEED = 55
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## 1. Setting Up the Environment

# %%
def make_ppo_agent(env, feature_extractor, seed, config=None, load=None, tensorboard_log=None, device='auto', custom_objects=None):
    if config is None:
        config = {}
        
    policy_kwargs = dict(
        features_extractor_class=feature_extractor,
        features_extractor_kwargs=dict(features_dim=256),
        normalize_images=False,
    )
    
    if 'policy_kwargs' in config:
        policy_kwargs.update(config.pop('policy_kwargs'))
    
    if load is not None:
        print('Loading model from', load)
        model = PPO.load(load, env=env, policy_kwargs=policy_kwargs, seed=seed, verbose=1, device=device, tensorboard_log=tensorboard_log, custom_objects=custom_objects, **config)
    else:
        model = PPO("CnnPolicy", env, policy_kwargs=policy_kwargs, seed=seed, verbose=1, device=device, tensorboard_log=tensorboard_log, **config)
    return model

# %%
NUM_ENVS = 32 #1024
SEE_FULL_OBS = True
base_wrapper_kwargs = {'full_obs': SEE_FULL_OBS}
aug_wrapper_kwargs = {'full_obs': SEE_FULL_OBS, 'subset': [0,1]}
std_vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED,
                               wrapper_class=BaseWrapper,
                               wrapper_kwargs=base_wrapper_kwargs,
                               monitor_dir='./logs/std')
std_vec_env = VecNormalize(std_vec_env, norm_obs=False, norm_reward=True)

aug_vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED,
                               wrapper_class=RandomRotateWrapper,
                               wrapper_kwargs=aug_wrapper_kwargs,
                               monitor_dir='./logs/aug')
aug_vec_env = VecNormalize(aug_vec_env, norm_obs=False, norm_reward=True)

eq_vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED,
                               wrapper_class=BaseWrapper,
                               wrapper_kwargs=base_wrapper_kwargs,
                               monitor_dir='./logs/eq')
eq_vec_env = VecNormalize(eq_vec_env, norm_obs=False, norm_reward=True)

aug_eq_vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED,
                               wrapper_class=RandomRotateWrapper,
                               wrapper_kwargs=aug_wrapper_kwargs,
                               monitor_dir='./logs/aug_eq')
aug_eq_vec_env = VecNormalize(aug_eq_vec_env, norm_obs=False, norm_reward=True)

# %%
def make_eval_env(wrapper_class=None, subset=None, full_obs=SEE_FULL_OBS, env_name=ENV_NAME):
    def _make_starting_env(env_name):
        if env_name == "MiniGrid-FourRooms-v0":
            env = gym.make(env_name, render_mode="rgb_array")
        else:
            env = env_name(render_mode="rgb_array")
        return env

    env = _make_starting_env(env_name=env_name)
    if wrapper_class is None:
        env = BaseWrapper(env, full_obs=full_obs)
    else:
        if subset is None:
            env = wrapper_class(env, full_obs=full_obs)
        else:
            env = wrapper_class(env, subset, full_obs=full_obs)
    env = Monitor(env)
    return env

# %%
eval_env = make_eval_env()
eval_90_env = make_eval_env(Rotate90Wrapper)
eval_180_env = make_eval_env(Rotate180Wrapper)
eval_270_env = make_eval_env(Rotate270Wrapper)
eval_rand_env = make_eval_env(RandomRotateWrapper, subset=[0, 1, 2, 3])
eval_0_90_env = make_eval_env(RandomRotateWrapper, subset=[0, 1])
eval_180_270_env = make_eval_env(RandomRotateWrapper, subset=[2, 3])

print(f"Environment: {ENV_NAME}")
print(f"Observation shape: {eval_env.observation_space.shape}")
print(f"Action space: {eval_env.action_space}")
# Out:
# Environment: <class 'envs.custom_fourrooms.FourRoomsEnv09'>
# Observation shape: (9, 9, 3)
# Action space: Discrete(3)

# %% [markdown]
# ## 2. PPO Default Hyperparameters
#
# Below are the default hyperparameters for PPO that can be configured:

# %%
n_steps = 64 #128
num_minibatches = 8
batch_size = int(n_steps * NUM_ENVS / num_minibatches)
print(f'Batch size: {batch_size}')
default_ppo_params = {
    "learning_rate": 3e-4,
    "n_steps": n_steps,
    "batch_size": batch_size,
    "n_epochs": 4,
    "gamma": 0.99,
    "gae_lambda": 0.95,
    "clip_range": 0.2,
    "clip_range_vf": None,
    "normalize_advantage": True,
    "ent_coef": 0.01,
    "vf_coef": 0.5,
    "max_grad_norm": 0.5,
}

def lr_schedule(starting_lr=3e-4):
    def scheduler(progress_remaining):
        return max(starting_lr * progress_remaining, 1e-4)
    return scheduler

# default_ppo_params["learning_rate"] = lr_schedule(default_ppo_params["learning_rate"])

standard_config = default_ppo_params.copy()
equivariant_config = default_ppo_params.copy()
# Out:
# Batch size: 256

# %% [markdown]
# ## 3. Training Agents

# %%
# %load_ext tensorboard
# %tensorboard --logdir {TENSORBOARD_LOG_DIR}

# %%
standard_agent = make_ppo_agent(
    std_vec_env, 
    feature_extractor=MinigridFeaturesExtractor, 
    seed=SEED,
    config=standard_config,
    load=None,#'model_checkpoints/full/9x9_standard_agent_10m',
    tensorboard_log=TENSORBOARD_LOG_DIR + "standard"
)
# print(f"Training standard CNN PPO for {TIMESTEPS} timesteps...")
# standard_agent.learn(total_timesteps=int(TIMESTEPS), tb_log_name="standard_run")
# print("Standard CNN training completed!")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
equivariant_agent = make_ppo_agent(
    eq_vec_env, 
    feature_extractor=SmallKernelC4EquivariantCNN, 
    seed=SEED,
    config=equivariant_config,
    load=None,#'model_checkpoints/full/9x9_eq_agent_10m',
    tensorboard_log=TENSORBOARD_LOG_DIR + "equivariant"
)
# print(f"Training equivariant CNN PPO for {TIMESTEPS} timesteps...")
# equivariant_agent.learn(total_timesteps=int(2e4), tb_log_name="equivariant_run")
# print("Equivariant CNN training completed!")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
aug_agent = make_ppo_agent(
    aug_vec_env, 
    feature_extractor=MinigridFeaturesExtractor, 
    seed=SEED,
    config=standard_config,
    load='model_checkpoints/full/9x9_aug_agent_10m.zip',
    tensorboard_log=TENSORBOARD_LOG_DIR + "augmented"
)
# print(f"Training augmented standard CNN PPO for {TIMESTEPS} timesteps...")
# aug_agent.learn(total_timesteps=int(TIMESTEPS), tb_log_name="augmented_run")
# print("Augmented standard CNN training completed!")
# Out:
# Loading model from model_checkpoints/full/9x9_aug_agent_10m.zip
# Wrapping the env in a VecTransposeImage.

# %%
almost_eq_agent = make_ppo_agent(
    eq_vec_env, 
    feature_extractor=MostlyC4EquivariantCNN, 
    seed=SEED,
    config=equivariant_config,
    load='model_checkpoints/full/maxpool2x2_9x9_eq_agent_10m.zip',
    custom_objects={ # model's features_extractor had different name during training
        "policy_kwargs": dict(
            features_extractor_class=MostlyC4EquivariantCNN,
            features_extractor_kwargs=dict(features_dim=256),
            normalize_images=False,
        )
    }
)

# %%
almost_eq_agent = make_ppo_agent(
    aug_vec_env, 
    feature_extractor=MostlyC4EquivariantCNN, 
    seed=SEED,
    config=standard_config,
    load=None,#'model_checkpoints/full/9x9_aug_agent_10m.zip',
    tensorboard_log=TENSORBOARD_LOG_DIR
)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
# aug_equivariant_agent = make_ppo_agent(
#     aug_eq_vec_env, 
#     feature_extractor=SmallKernelC4EquivariantCNN, 
#     seed=SEED,
#     config=equivariant_config,
#     load='model_checkpoints/full/9x9_aug_eq_agent_10m.zip',
#     tensorboard_log=TENSORBOARD_LOG_DIR + "augmented_equivariant"
# )
# # print(f"Training augmented equivariant CNN PPO for {TIMESTEPS} timesteps...")
# # aug_equivariant_agent.learn(total_timesteps=int(TIMESTEPS), tb_log_name="augmented_equivariant_run")
# # print("Augmented equivariant CNN training completed!")

# %% [markdown]
# # 4. Evaluation

# %%
def eval_success(model, env, n_episodes=100):
    success = 0
    returns = []
    for ep in range(n_episodes):
        obs, _ = env.reset()
        done = False
        truncated = False
        total_reward = 0
        while not (done or truncated):
            action, _ = model.predict(obs, deterministic=False)
            obs, reward, done, truncated, info = env.step(action)
            total_reward += reward
        returns.append(total_reward)
        if done and reward > 0:
            success += 1
    success_rate = success / n_episodes
    avg_return = np.mean(returns)
    std_return = np.std(returns)
    se_success = np.sqrt(success_rate * (1 - success_rate) / n_episodes)
    return success_rate, avg_return, se_success, std_return

def run_eval_success_experiment(env):
    sr_std, ret_std, se_std, _ = eval_success(standard_agent, env)
    sr_aug, ret_aug, se_aug, _ = eval_success(aug_agent, env)
    sr_equiv, ret_equiv, se_equiv, _ = eval_success(equivariant_agent, env)
    # sr_aug_eq, ret_aug_eq = eval_success(aug_equivariant_agent, env)
    print(f"Success rate (standard): {sr_std:.2f} +/- {se_std:.2f}, Average return: {ret_std:.2f}")
    print(f"Success rate (augmented): {sr_aug:.2f} +/- {se_aug:.2f}, Average return: {ret_aug:.2f}")
    print(f"Success rate (equivariant): {sr_equiv:.2f} +/- {se_equiv:.2f}, Average return: {ret_equiv:.2f}")
    # print(f"Success rate (augmented equivariant): {sr_aug_eq:.2f}, Average return: {ret_aug_eq:.2f}")

# %%
print('Base Environment')
run_eval_success_experiment(eval_env)
print('------'*10)

print("Random Environment")
run_eval_success_experiment(eval_rand_env)
print('------'*10)

print("90-degree Environment")
run_eval_success_experiment(eval_90_env)
print('------'*10)

print("180-degree Environment")
run_eval_success_experiment(eval_180_env)
print('------'*10)

print("270-degree Environment")
run_eval_success_experiment(eval_270_env)
print('------'*10)

print("180-270-degree Environment")
run_eval_success_experiment(eval_180_270_env)
# Out:
# Base Environment
# Success rate (standard): 0.98, Average return: 0.84
# Success rate (augmented): 1.00, Average return: 0.86
# Success rate (equivariant): 0.93, Average return: 0.80
# ------------------------------------------------------------
# Random Environment
# Success rate (standard): 0.22, Average return: 0.18
# Success rate (augmented): 0.50, Average return: 0.43
# Success rate (equivariant): 0.89, Average return: 0.76
# ------------------------------------------------------------
# 90-degree Environment
# Success rate (standard): 0.00, Average return: 0.00
# Success rate (augmented): 1.00, Average return: 0.86
# Success rate (equivariant): 0.90, Average return: 0.78
# ------------------------------------------------------------
# 180-degree Environment
# Success rate (standard): 0.10, Average return: 0.07
# Success rate (augmented): 0.01, Average return: 0.00
# Success rate (equivariant): 0.88, Average return: 0.75
# ------------------------------------------------------------
# 270-degree Environment
# Success rate (standard): 0.00, Average return: 0.00
# Success rate (augmented): 0.02, Average return: 0.01
# Success rate (equivariant): 0.91, Average return: 0.78
# ------------------------------------------------------------
# 180-270-degree Environment
# Success rate (standard): 0.00, Average return: 0.00
# Success rate (augmented): 0.01, Average return: 0.00
# Success rate (equivariant): 0.91, Average return: 0.79

# %%
def plot_test_results(test_results, errors, labels, title, y_label):

    x = np.arange(len(labels))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.bar(x, test_results, width, yerr=errors, capsize=5, color=['blue', 'orange', 'green', 'red'], alpha=0.7)

    ax.set_xlabel("Agent Types")
    ax.set_ylabel(y_label)
    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_ylim(0, 1.1)

    for bar, err in zip(bars, errors):
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height + err), 
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

    plt.tight_layout()
    plt.show()

def get_chart_info(env):
    sr_std, r_std, se_std, re_std = eval_success(standard_agent, env)
    sr_aug, r_aug, se_aug, re_aug = eval_success(aug_agent, env)
    sr_almost_eq, r_almost_eq, se_almost_eq, re_almost_eq = eval_success(almost_eq_agent, env)
    sr_equiv, r_equiv, se_equiv, re_equiv = eval_success(equivariant_agent, env)

    success_rates = [sr_std, sr_aug, sr_almost_eq, sr_equiv]
    rewards = [r_std, r_aug, r_almost_eq, r_equiv]
    success_errors = [se_std, se_aug, se_almost_eq, se_equiv]
    reward_errors = [re_std, re_aug, re_almost_eq, re_equiv]
    labels = ['Standard', 'Augmented', 'Mostly Equivariant', 'Fully Equivariant']
    return success_rates, rewards, success_errors, reward_errors, labels

# %%
base_success_rates, base_rewards, base_errors, base_reward_errors, base_labels = get_chart_info(eval_env)
rot_90_success_rates, rot_90_rewards, rot_90_errors, rot_90_reward_errors, rot_90_labels = get_chart_info(eval_90_env)
rot_180_success_rates, rot_180_rewards, rot_180_errors, rot_180_reward_errors, rot_180_labels = get_chart_info(eval_180_env)
rot_270_success_rates, rot_270_rewards, rot_270_errors, rot_270_reward_errors, rot_270_labels = get_chart_info(eval_270_env)

# %%
plot_test_results(base_success_rates, base_errors, base_labels, title="Success Rates on Base Environment (0°)", y_label="Success Rate")
plot_test_results(rot_90_success_rates, rot_90_errors, rot_90_labels, title="Success Rates on 90° Rotated Environment", y_label="Success Rate")
plot_test_results(rot_180_success_rates, rot_180_errors, rot_180_labels, title="Success Rates on 180° Rotated Environment", y_label="Success Rate")
plot_test_results(rot_270_success_rates, rot_270_errors, rot_270_labels, title="Success Rates on 270° Rotated Environment", y_label="Success Rate")

plot_test_results(base_rewards, base_reward_errors, base_labels, title="Average Returns on Base Environment (0°)", y_label="Average Return")
plot_test_results(rot_90_rewards, rot_90_reward_errors, rot_90_labels, title="Average Returns on 90° Rotated Environment", y_label="Average Return")
plot_test_results(rot_180_rewards, rot_180_reward_errors, rot_180_labels, title="Average Returns on 180° Rotated Environment", y_label="Average Return")
plot_test_results(rot_270_rewards, rot_270_reward_errors, rot_270_labels, title="Average Returns on 270° Rotated Environment", y_label="Average Return")

# %% [markdown]
# # 5. Training Curves

# %%
def moving_average(values, window):
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folders, title="Learning Curve"):
    for log_folder in log_folders:
        x, y = ts2xy(load_results(log_folder), "timesteps")
        y = moving_average(y, window=1000)
        x = x[len(x) - len(y) :]

        fig = plt.figure(title)
        plt.plot(x, y)
        plt.xlabel("Number of Timesteps")
        plt.ylabel("Rewards")
        plt.title(title)
    plt.legend(['Standard', 'Augmented', 'Mostly Equivariant', 'Fully Equivariant'])
    plt.show()

# %%
plot_results(['./logs/std', './logs/aug', './logs/mostly_eq', './logs/eq'], title="Training Curve")

# %% [markdown]
# # 6. Visualizing Custom PPO Agent

# %%
env_class = lambda: make_eval_env(Rotate270Wrapper)
frames = capture_side_by_side_comparison(
    models=[standard_agent, aug_agent, equivariant_agent],
    envs=[env_class] * 3,
    labels=["Standard", "Augmented", "Equivariant"],
    num_steps=25,
    rotation=3,
    output_path="vids/comparison_video_270.mp4",
    fps=5
)
display(create_animation(frames))
# Out:
# Video saved to vids/comparison_video_270.mp4
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc30e27d3604e40709a6ebb13549312dd">
#   <div class="anim-controls">
#     <input id="_anim_sliderc30e27d3604e40709a6ebb13549312dd" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc30e27d3604e40709a6ebb13549312dd.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animc30e27d3604e40709a6ebb13549312dd.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animc30e27d3604e40709a6ebb13549312dd.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animc30e27d3604e40709a6ebb13549312dd.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animc30e27d3604e40709a6ebb13549312dd.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animc30e27d3604e40709a6ebb13549312dd.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animc30e27d3604e40709a6ebb13549312dd.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animc30e27d3604e40709a6ebb13549312dd.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animc30e27d3604e40709a6ebb13549312dd.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animc30e27d3604e40709a6ebb13549312dd.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectc30e27d3604e40709a6ebb13549312dd"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c30e27d3604e40709a6ebb13549312dd"
#              >
#       <label for="_anim_radio1_c30e27d3604e40709a6ebb13549312dd">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c30e27d3604e40709a6ebb13549312dd"
#              checked>
#       <label for="_anim_radio2_c30e27d3604e40709a6ebb13549312dd">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c30e27d3604e40709a6ebb13549312dd"
#              >
#       <label for="_anim_radio3_c30e27d3604e40709a6ebb13549312dd">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc30e27d3604e40709a6ebb13549312dd";
#     var slider_id = "_anim_sliderc30e27d3604e40709a6ebb13549312dd";
#     var loop_select_id = "_anim_loop_selectc30e27d3604e40709a6ebb13549312dd";
#     var frames = new Array(25);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAJSpJR

# %%
std_frames = capture_frames_sb3(equivariant_agent, eval_env, rotation=0)
display(create_animation(std_frames, save_path='./vids/eq_0.mp4'))

frames_90 = capture_frames_sb3(equivariant_agent, eval_90_env, rotation=1)
display(create_animation(frames_90, save_path='./vids/eq_90.mp4'))

frames_180 = capture_frames_sb3(equivariant_agent, eval_180_env, rotation=2)
display(create_animation(frames_180, save_path='./vids/eq_180.mp4'))

frames_270 = capture_frames_sb3(equivariant_agent, eval_270_env, rotation=3)
display(create_animation(frames_270, save_path='./vids/eq_270.mp4'))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img00677ffaf22e41a2ada812f41f4f8b80">
#   <div class="anim-controls">
#     <input id="_anim_slider00677ffaf22e41a2ada812f41f4f8b80" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim00677ffaf22e41a2ada812f41f4f8b80.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim00677ffaf22e41a2ada812f41f4f8b80.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select00677ffaf22e41a2ada812f41f4f8b80"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_00677ffaf22e41a2ada812f41f4f8b80"
#              >
#       <label for="_anim_radio1_00677ffaf22e41a2ada812f41f4f8b80">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_00677ffaf22e41a2ada812f41f4f8b80"
#              checked>
#       <label for="_anim_radio2_00677ffaf22e41a2ada812f41f4f8b80">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_00677ffaf22e41a2ada812f41f4f8b80"
#              >
#       <label for="_anim_radio3_00677ffaf22e41a2ada812f41f4f8b80">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img00677ffaf22e41a2ada812f41f4f8b80";
#     var slider_id = "_anim_slider00677ffaf22e41a2ada812f41f4f8b80";
#     var loop_select_id = "_anim_loop_select00677ffaf22e41a2ada812f41f4f8b80";
#     var frames = new Array(17);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGhNJR
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img1cc98c52cc984293809fd24454f78cbe">
#   <div class="anim-controls">
#     <input id="_anim_slider1cc98c52cc984293809fd24454f78cbe" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim1cc98c52cc984293809fd24454f78cbe.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim1cc98c52cc984293809fd24454f78cbe.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim1cc98c52cc984293809fd24454f78cbe.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim1cc98c52cc984293809fd24454f78cbe.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim1cc98c52cc984293809fd24454f78cbe.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim1cc98c52cc984293809fd24454f78cbe.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim1cc98c52cc984293809fd24454f78cbe.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim1cc98c52cc984293809fd24454f78cbe.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim1cc98c52cc984293809fd24454f78cbe.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim1cc98c52cc984293809fd24454f78cbe.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select1cc98c52cc984293809fd24454f78cbe"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_1cc98c52cc984293809fd24454f78cbe"
#              >
#       <label for="_anim_radio1_1cc98c52cc984293809fd24454f78cbe">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_1cc98c52cc984293809fd24454f78cbe"
#              checked>
#       <label for="_anim_radio2_1cc98c52cc984293809fd24454f78cbe">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_1cc98c52cc984293809fd24454f78cbe"
#              >
#       <label for="_anim_radio3_1cc98c52cc984293809fd24454f78cbe">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1cc98c52cc984293809fd24454f78cbe";
#     var slider_id = "_anim_slider1cc98c52cc984293809fd24454f78cbe";
#     var loop_select_id = "_anim_loop_select1cc98c52cc984293809fd24454f78cbe";
#     var frames = new Array(17);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGkJJR
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img765db94d7c7349d593180d76217db6b5">
#   <div class="anim-controls">
#     <input id="_anim_slider765db94d7c7349d593180d76217db6b5" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim765db94d7c7349d593180d76217db6b5.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim765db94d7c7349d593180d76217db6b5.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim765db94d7c7349d593180d76217db6b5.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim765db94d7c7349d593180d76217db6b5.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim765db94d7c7349d593180d76217db6b5.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim765db94d7c7349d593180d76217db6b5.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim765db94d7c7349d593180d76217db6b5.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim765db94d7c7349d593180d76217db6b5.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim765db94d7c7349d593180d76217db6b5.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim765db94d7c7349d593180d76217db6b5.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select765db94d7c7349d593180d76217db6b5"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_765db94d7c7349d593180d76217db6b5"
#              >
#       <label for="_anim_radio1_765db94d7c7349d593180d76217db6b5">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_765db94d7c7349d593180d76217db6b5"
#              checked>
#       <label for="_anim_radio2_765db94d7c7349d593180d76217db6b5">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_765db94d7c7349d593180d76217db6b5"
#              >
#       <label for="_anim_radio3_765db94d7c7349d593180d76217db6b5">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img765db94d7c7349d593180d76217db6b5";
#     var slider_id = "_anim_slider765db94d7c7349d593180d76217db6b5";
#     var loop_select_id = "_anim_loop_select765db94d7c7349d593180d76217db6b5";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGnBJ
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgacd38cc024e74b3e93644c65ed26c74a">
#   <div class="anim-controls">
#     <input id="_anim_slideracd38cc024e74b3e93644c65ed26c74a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animacd38cc024e74b3e93644c65ed26c74a.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animacd38cc024e74b3e93644c65ed26c74a.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animacd38cc024e74b3e93644c65ed26c74a.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animacd38cc024e74b3e93644c65ed26c74a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animacd38cc024e74b3e93644c65ed26c74a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animacd38cc024e74b3e93644c65ed26c74a.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animacd38cc024e74b3e93644c65ed26c74a.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animacd38cc024e74b3e93644c65ed26c74a.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animacd38cc024e74b3e93644c65ed26c74a.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animacd38cc024e74b3e93644c65ed26c74a.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectacd38cc024e74b3e93644c65ed26c74a"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_acd38cc024e74b3e93644c65ed26c74a"
#              >
#       <label for="_anim_radio1_acd38cc024e74b3e93644c65ed26c74a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_acd38cc024e74b3e93644c65ed26c74a"
#              checked>
#       <label for="_anim_radio2_acd38cc024e74b3e93644c65ed26c74a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_acd38cc024e74b3e93644c65ed26c74a"
#              >
#       <label for="_anim_radio3_acd38cc024e74b3e93644c65ed26c74a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgacd38cc024e74b3e93644c65ed26c74a";
#     var slider_id = "_anim_slideracd38cc024e74b3e93644c65ed26c74a";
#     var loop_select_id = "_anim_loop_selectacd38cc024e74b3e93644c65ed26c74a";
#     var frames = new Array(14);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGjFJR

# %%
std_frames = capture_frames_sb3(aug_agent, eval_env, rotation=0)
display(create_animation(std_frames, save_path='./vids/aug_0.mp4'))

frames_90 = capture_frames_sb3(aug_agent, eval_90_env, rotation=1)
display(create_animation(frames_90, save_path='./vids/aug_90.mp4'))

frames_180 = capture_frames_sb3(aug_agent, eval_180_env, rotation=2)
display(create_animation(frames_180, save_path='./vids/aug_180.mp4'))

frames_270 = capture_frames_sb3(aug_agent, eval_270_env, rotation=3)
display(create_animation(frames_270, save_path='./vids/aug_270.mp4'))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img3f494fab15d14136856f429ecb9a105d">
#   <div class="anim-controls">
#     <input id="_anim_slider3f494fab15d14136856f429ecb9a105d" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim3f494fab15d14136856f429ecb9a105d.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim3f494fab15d14136856f429ecb9a105d.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim3f494fab15d14136856f429ecb9a105d.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim3f494fab15d14136856f429ecb9a105d.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim3f494fab15d14136856f429ecb9a105d.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim3f494fab15d14136856f429ecb9a105d.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim3f494fab15d14136856f429ecb9a105d.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim3f494fab15d14136856f429ecb9a105d.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim3f494fab15d14136856f429ecb9a105d.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim3f494fab15d14136856f429ecb9a105d.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select3f494fab15d14136856f429ecb9a105d"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_3f494fab15d14136856f429ecb9a105d"
#              >
#       <label for="_anim_radio1_3f494fab15d14136856f429ecb9a105d">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_3f494fab15d14136856f429ecb9a105d"
#              checked>
#       <label for="_anim_radio2_3f494fab15d14136856f429ecb9a105d">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_3f494fab15d14136856f429ecb9a105d"
#              >
#       <label for="_anim_radio3_3f494fab15d14136856f429ecb9a105d">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3f494fab15d14136856f429ecb9a105d";
#     var slider_id = "_anim_slider3f494fab15d14136856f429ecb9a105d";
#     var loop_select_id = "_anim_loop_select3f494fab15d14136856f429ecb9a105d";
#     var frames = new Array(14);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGglJR
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgebf83cc153fc48159655c802505fb6d0">
#   <div class="anim-controls">
#     <input id="_anim_sliderebf83cc153fc48159655c802505fb6d0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animebf83cc153fc48159655c802505fb6d0.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animebf83cc153fc48159655c802505fb6d0.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animebf83cc153fc48159655c802505fb6d0.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animebf83cc153fc48159655c802505fb6d0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animebf83cc153fc48159655c802505fb6d0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animebf83cc153fc48159655c802505fb6d0.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animebf83cc153fc48159655c802505fb6d0.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animebf83cc153fc48159655c802505fb6d0.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animebf83cc153fc48159655c802505fb6d0.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animebf83cc153fc48159655c802505fb6d0.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectebf83cc153fc48159655c802505fb6d0"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_ebf83cc153fc48159655c802505fb6d0"
#              >
#       <label for="_anim_radio1_ebf83cc153fc48159655c802505fb6d0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_ebf83cc153fc48159655c802505fb6d0"
#              checked>
#       <label for="_anim_radio2_ebf83cc153fc48159655c802505fb6d0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_ebf83cc153fc48159655c802505fb6d0"
#              >
#       <label for="_anim_radio3_ebf83cc153fc48159655c802505fb6d0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgebf83cc153fc48159655c802505fb6d0";
#     var slider_id = "_anim_sliderebf83cc153fc48159655c802505fb6d0";
#     var loop_select_id = "_anim_loop_selectebf83cc153fc48159655c802505fb6d0";
#     var frames = new Array(14);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGkFJR
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img956791046dee4cb3a7c36e1b5e0e0591">
#   <div class="anim-controls">
#     <input id="_anim_slider956791046dee4cb3a7c36e1b5e0e0591" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim956791046dee4cb3a7c36e1b5e0e0591.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim956791046dee4cb3a7c36e1b5e0e0591.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select956791046dee4cb3a7c36e1b5e0e0591"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_956791046dee4cb3a7c36e1b5e0e0591"
#              >
#       <label for="_anim_radio1_956791046dee4cb3a7c36e1b5e0e0591">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_956791046dee4cb3a7c36e1b5e0e0591"
#              checked>
#       <label for="_anim_radio2_956791046dee4cb3a7c36e1b5e0e0591">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_956791046dee4cb3a7c36e1b5e0e0591"
#              >
#       <label for="_anim_radio3_956791046dee4cb3a7c36e1b5e0e0591">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img956791046dee4cb3a7c36e1b5e0e0591";
#     var slider_id = "_anim_slider956791046dee4cb3a7c36e1b5e0e0591";
#     var loop_select_id = "_anim_loop_select956791046dee4cb3a7c36e1b5e0e0591";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGl5J
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img97d9b9e8f736448c9a163d033c65454c">
#   <div class="anim-controls">
#     <input id="_anim_slider97d9b9e8f736448c9a163d033c65454c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim97d9b9e8f736448c9a163d033c65454c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim97d9b9e8f736448c9a163d033c65454c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim97d9b9e8f736448c9a163d033c65454c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim97d9b9e8f736448c9a163d033c65454c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim97d9b9e8f736448c9a163d033c65454c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim97d9b9e8f736448c9a163d033c65454c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim97d9b9e8f736448c9a163d033c65454c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim97d9b9e8f736448c9a163d033c65454c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim97d9b9e8f736448c9a163d033c65454c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim97d9b9e8f736448c9a163d033c65454c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select97d9b9e8f736448c9a163d033c65454c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_97d9b9e8f736448c9a163d033c65454c"
#              >
#       <label for="_anim_radio1_97d9b9e8f736448c9a163d033c65454c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_97d9b9e8f736448c9a163d033c65454c"
#              checked>
#       <label for="_anim_radio2_97d9b9e8f736448c9a163d033c65454c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_97d9b9e8f736448c9a163d033c65454c"
#              >
#       <label for="_anim_radio3_97d9b9e8f736448c9a163d033c65454c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img97d9b9e8f736448c9a163d033c65454c";
#     var slider_id = "_anim_slider97d9b9e8f736448c9a163d033c65454c";
#     var loop_select_id = "_anim_loop_select97d9b9e8f736448c9a163d033c65454c";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGlNJ

# %%
std_frames = capture_frames_sb3(standard_agent, eval_env, rotation=0)
display(create_animation(std_frames, save_path='./vids/std_0.mp4'))

frames_90 = capture_frames_sb3(standard_agent, eval_90_env, rotation=1)
display(create_animation(frames_90, save_path='./vids/std_90.mp4'))

frames_180 = capture_frames_sb3(standard_agent, eval_180_env, rotation=2)
display(create_animation(frames_180, save_path='./vids/std_180.mp4'))

frames_270 = capture_frames_sb3(standard_agent, eval_270_env, rotation=3)
display(create_animation(frames_270, save_path='./vids/std_270.mp4'))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img1567798f034c46c895b2f6ceaae2136b">
#   <div class="anim-controls">
#     <input id="_anim_slider1567798f034c46c895b2f6ceaae2136b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim1567798f034c46c895b2f6ceaae2136b.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim1567798f034c46c895b2f6ceaae2136b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim1567798f034c46c895b2f6ceaae2136b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim1567798f034c46c895b2f6ceaae2136b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim1567798f034c46c895b2f6ceaae2136b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim1567798f034c46c895b2f6ceaae2136b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim1567798f034c46c895b2f6ceaae2136b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim1567798f034c46c895b2f6ceaae2136b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim1567798f034c46c895b2f6ceaae2136b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim1567798f034c46c895b2f6ceaae2136b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select1567798f034c46c895b2f6ceaae2136b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_1567798f034c46c895b2f6ceaae2136b"
#              >
#       <label for="_anim_radio1_1567798f034c46c895b2f6ceaae2136b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_1567798f034c46c895b2f6ceaae2136b"
#              checked>
#       <label for="_anim_radio2_1567798f034c46c895b2f6ceaae2136b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_1567798f034c46c895b2f6ceaae2136b"
#              >
#       <label for="_anim_radio3_1567798f034c46c895b2f6ceaae2136b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1567798f034c46c895b2f6ceaae2136b";
#     var slider_id = "_anim_slider1567798f034c46c895b2f6ceaae2136b";
#     var loop_select_id = "_anim_loop_select1567798f034c46c895b2f6ceaae2136b";
#     var frames = new Array(14);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGhBJR
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img73f7db2a169443c2a499a3b7a9788a18">
#   <div class="anim-controls">
#     <input id="_anim_slider73f7db2a169443c2a499a3b7a9788a18" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim73f7db2a169443c2a499a3b7a9788a18.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim73f7db2a169443c2a499a3b7a9788a18.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim73f7db2a169443c2a499a3b7a9788a18.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim73f7db2a169443c2a499a3b7a9788a18.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim73f7db2a169443c2a499a3b7a9788a18.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim73f7db2a169443c2a499a3b7a9788a18.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim73f7db2a169443c2a499a3b7a9788a18.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim73f7db2a169443c2a499a3b7a9788a18.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim73f7db2a169443c2a499a3b7a9788a18.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim73f7db2a169443c2a499a3b7a9788a18.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select73f7db2a169443c2a499a3b7a9788a18"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_73f7db2a169443c2a499a3b7a9788a18"
#              >
#       <label for="_anim_radio1_73f7db2a169443c2a499a3b7a9788a18">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_73f7db2a169443c2a499a3b7a9788a18"
#              checked>
#       <label for="_anim_radio2_73f7db2a169443c2a499a3b7a9788a18">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_73f7db2a169443c2a499a3b7a9788a18"
#              >
#       <label for="_anim_radio3_73f7db2a169443c2a499a3b7a9788a18">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img73f7db2a169443c2a499a3b7a9788a18";
#     var slider_id = "_anim_slider73f7db2a169443c2a499a3b7a9788a18";
#     var loop_select_id = "_anim_loop_select73f7db2a169443c2a499a3b7a9788a18";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGidJ
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img3b99aeea24694979b50dad1d56739f8c">
#   <div class="anim-controls">
#     <input id="_anim_slider3b99aeea24694979b50dad1d56739f8c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim3b99aeea24694979b50dad1d56739f8c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim3b99aeea24694979b50dad1d56739f8c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim3b99aeea24694979b50dad1d56739f8c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim3b99aeea24694979b50dad1d56739f8c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim3b99aeea24694979b50dad1d56739f8c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim3b99aeea24694979b50dad1d56739f8c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim3b99aeea24694979b50dad1d56739f8c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim3b99aeea24694979b50dad1d56739f8c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim3b99aeea24694979b50dad1d56739f8c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim3b99aeea24694979b50dad1d56739f8c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select3b99aeea24694979b50dad1d56739f8c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_3b99aeea24694979b50dad1d56739f8c"
#              >
#       <label for="_anim_radio1_3b99aeea24694979b50dad1d56739f8c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_3b99aeea24694979b50dad1d56739f8c"
#              checked>
#       <label for="_anim_radio2_3b99aeea24694979b50dad1d56739f8c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_3b99aeea24694979b50dad1d56739f8c"
#              >
#       <label for="_anim_radio3_3b99aeea24694979b50dad1d56739f8c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3b99aeea24694979b50dad1d56739f8c";
#     var slider_id = "_anim_slider3b99aeea24694979b50dad1d56739f8c";
#     var loop_select_id = "_anim_loop_select3b99aeea24694979b50dad1d56739f8c";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGmZJ
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img1988d37f71e34ea4a62c583bcb52803a">
#   <div class="anim-controls">
#     <input id="_anim_slider1988d37f71e34ea4a62c583bcb52803a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim1988d37f71e34ea4a62c583bcb52803a.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim1988d37f71e34ea4a62c583bcb52803a.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim1988d37f71e34ea4a62c583bcb52803a.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim1988d37f71e34ea4a62c583bcb52803a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim1988d37f71e34ea4a62c583bcb52803a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim1988d37f71e34ea4a62c583bcb52803a.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim1988d37f71e34ea4a62c583bcb52803a.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim1988d37f71e34ea4a62c583bcb52803a.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim1988d37f71e34ea4a62c583bcb52803a.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim1988d37f71e34ea4a62c583bcb52803a.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select1988d37f71e34ea4a62c583bcb52803a"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_1988d37f71e34ea4a62c583bcb52803a"
#              >
#       <label for="_anim_radio1_1988d37f71e34ea4a62c583bcb52803a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_1988d37f71e34ea4a62c583bcb52803a"
#              checked>
#       <label for="_anim_radio2_1988d37f71e34ea4a62c583bcb52803a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_1988d37f71e34ea4a62c583bcb52803a"
#              >
#       <label for="_anim_radio3_1988d37f71e34ea4a62c583bcb52803a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1988d37f71e34ea4a62c583bcb52803a";
#     var slider_id = "_anim_slider1988d37f71e34ea4a62c583bcb52803a";
#     var loop_select_id = "_anim_loop_select1988d37f71e34ea4a62c583bcb52803a";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGlRJ

# %%
print("Standard CNN PPO Architecture:")
print(standard_agent.policy)
print("\nC4 Equivariant CNN PPO Architecture:")
print(equivariant_agent.policy)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

std_params = count_parameters(standard_agent.policy)
mostly_eq_params = count_parameters(almost_eq_agent.policy)
eq_params = count_parameters(equivariant_agent.policy)
print(f"\nParameter Count Comparison:")
print(f"Standard CNN PPO: {std_params:,} parameters")
print(f"Mostly C4 Equivariant CNN PPO: {mostly_eq_params:,} parameters")
print(f"C4 Equivariant CNN PPO: {eq_params:,} parameters")

labels = ['Standard CNN', 'Mostly C4 Equivariant CNN', 'C4 Equivariant CNN']
values = [std_params, mostly_eq_params, eq_params]
plt.figure(figsize=(8, 5))
plt.bar(labels, values)
plt.title('Parameter Count Comparison')
plt.ylabel('Number of Parameters')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for i, v in enumerate(values):
    plt.text(i, v + 0.5, f"{v:,}", ha='center')
plt.show()
# Out:
# Standard CNN PPO Architecture:
# ActorCriticCnnPolicy(
#   (features_extractor): MinigridFeaturesExtractor(
#     (cnn): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU()
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#       (8): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#     )
#   )
#   (pi_features_extractor): MinigridFeaturesExtractor(
#     (cnn): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU()
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#       (8): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#     )
#   )
#   (vf_features_extractor): MinigridFeaturesExtractor(
#     (cnn): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU()
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#       (8): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=256, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=256, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=3, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )
#
# C4 Equivariant CNN PPO Architecture:
# ActorCriticCnnPolicy(
#   (features_extractor): SmallKernelC4EquivariantCNN(
#     (equivariant_model): SequentialModule(
#       (0): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {irrep_0 (x3)}(3)], [C4_on_R2[(None, 4)]: {regular (x32)}(128)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x32)}(128)])
#         (2): PointwiseMaxPool2D()
#       )
#       (1): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {regular (x32)}(128)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#         (2): PointwiseMaxPool2D()
#       )
#       (2): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#       )
#     )
#     (group_pool): GroupPooling([C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#     (fc): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=64, out_features=256, bias=True)
#       (2): ReLU()
#     )
#   )
#   (pi_features_extractor): SmallKernelC4EquivariantCNN(
#     (equivariant_model): SequentialModule(
#       (0): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {irrep_0 (x3)}(3)], [C4_on_R2[(None, 4)]: {regular (x32)}(128)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x32)}(128)])
#         (2): PointwiseMaxPool2D()
#       )
#       (1): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {regular (x32)}(128)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#         (2): PointwiseMaxPool2D()
#       )
#       (2): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#       )
#     )
#     (group_pool): GroupPooling([C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#     (fc): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=64, out_features=256, bias=True)
#       (2): ReLU()
#     )
#   )
#   (vf_features_extractor): SmallKernelC4EquivariantCNN(
#     (equivariant_model): SequentialModule(
#       (0): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {irrep_0 (x3)}(3)], [C4_on_R2[(None, 4)]: {regular (x32)}(128)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x32)}(128)])
#         (2): PointwiseMaxPool2D()
#       )
#       (1): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {regular (x32)}(128)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#         (2): PointwiseMaxPool2D()
#       )
#       (2): SequentialModule(
#         (0): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1)
#         (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#       )
#     )
#     (group_pool): GroupPooling([C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#     (fc): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=64, out_features=256, bias=True)
#       (2): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=256, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=256, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=3, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )
#
# Parameter Count Comparison:
# Standard CNN PPO: 266,052 parameters
# Mostly C4 Equivariant CNN PPO: 206,308 parameters
# C4 Equivariant CNN PPO: 206,308 parameters

# %% [markdown]
# # 7. Testing Equivariance of Agents

# %%
def test_equivariance(agent, env, transform_fn, num_steps=5):
    obs, _ = env.reset()
    for step in range(num_steps):
        obs_to_tensor = agent.policy.obs_to_tensor(obs)[0]
        orig_dist_probs = agent.policy.get_distribution(obs_to_tensor).distribution.probs
        
        transformed_obs = transform_fn(obs)
        transformed_obs_to_tensor = agent.policy.obs_to_tensor(transformed_obs)[0]
        transformed_dist_probs = agent.policy.get_distribution(transformed_obs_to_tensor).distribution.probs

        if not torch.allclose(orig_dist_probs, transformed_dist_probs, atol=1e-6):
            print(f"Step {step}: Original probs={orig_dist_probs}, Transformed probs={transformed_dist_probs}")
            print(f"Equivariance failed at step {step}")
            return False
        
        random_action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(random_action)
        
        if terminated or truncated:
            # print(f"Episode ended at step {step+1}")
            obs, _ = env.reset()
            # break
            
    print(f"Equivariance test passed for {num_steps} steps.")
    return True

def rotate_observation_90(obs):
    return np.rot90(obs, k=1, axes=(0, 1)).copy()

num_steps = 1000
rotate_fn = rotate_observation_90

is_equivariant = test_equivariance(equivariant_agent, eval_env, rotate_fn, num_steps)
print(f"\nIs the agent equivariant under 90-degree rotation? {is_equivariant}")

# print("\nTesting standard agent (expected to fail):")
# is_equivariant_std = test_equivariance(standard_agent, eval_env, rotate_fn, num_steps=num_steps)
# print(f"\nIs the standard agent equivariant under 90-degree rotation? {is_equivariant_std}")

print("\nTesting almost equivariant agent:")
is_equivariant_almost_eq = test_equivariance(almost_eq_agent, eval_env, rotate_fn, num_steps)
print(f"\nIs the almost equivariant agent equivariant under 90-degree rotation? {is_equivariant_almost_eq}")
# Out:
# Step 0: Original probs=tensor([[0.3343, 0.3319, 0.3338]], grad_fn=<SoftmaxBackward0>), Transformed probs=tensor([[0.3339, 0.3321, 0.3340]], grad_fn=<SoftmaxBackward0>)
# Equivariance failed at step 0
#
# Is the agent equivariant under 90-degree rotation? False
#
# Testing almost equivariant agent (expected to fail):
# Equivariance test passed for 1000 steps.
#
# Is the almost equivariant agent equivariant under 90-degree rotation? True

# %%
import escnn.nn as enn
from escnn import gspaces
def test_feature_invariance(agent, obs, transform_fn):
    device = agent.device

    obs_tensor = torch.tensor(obs, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0).to(device)
    rotated_obs = transform_fn(obs)
    rotated_tensor = torch.tensor(rotated_obs, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0).to(device)
    print(obs_tensor.shape, rotated_tensor.shape)
    extractor = agent.policy.features_extractor

    with torch.no_grad():
        x1 = extractor.equivariant_model(enn.GeometricTensor(obs_tensor, extractor.input_type))
        # x1 = x1.tensor
        x1 = extractor.group_pool(x1).tensor
        x2 = extractor.equivariant_model(enn.GeometricTensor(rotated_tensor, extractor.input_type))
        # x2 = x2.tensor
        x2 = extractor.group_pool(x2).tensor
        # x1 = extractor(obs_tensor)
        # x2 = extractor(rotated_tensor)

    diff = torch.norm(x1 - x2).item()
    print(f"Feature L2 difference (after GroupPooling): {diff:.6f}")


def test_group_action_invariance(agent, obs):
    device = agent.device
    extractor = agent.policy.features_extractor
    G = extractor.r2_act  # C4 group space

    # Prepare input
    obs_tensor = torch.tensor(obs, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0).to(device)
    x = enn.GeometricTensor(obs_tensor, extractor.input_type)

    rot90 = G.fibergroup.element(2)  # 90 degrees
    x_rot = x.transform(rot90)

    with torch.no_grad():
        y = extractor.equivariant_model(x)
        y_rot = extractor.equivariant_model(x_rot)

        pooled_y = extractor.group_pool(y).tensor
        pooled_y_rot = extractor.group_pool(y_rot).tensor

    diff = torch.norm(pooled_y - pooled_y_rot).item()
    print(f"Invariant feature L2 diff (via e2cnn group action): {diff:.6f}")

obs, _ = eval_env.reset()
dummy = np.random.randn(9, 9, 3)
# dummy[2:7, 2:7, 0] = 1.0  # red square
test_feature_invariance(equivariant_agent, obs, rotate_observation_90)
test_group_action_invariance(equivariant_agent, dummy)
# Out:
# torch.Size([1, 3, 9, 9]) torch.Size([1, 3, 9, 9])
# Feature L2 difference (after GroupPooling): 0.000003
# Invariant feature L2 diff (via e2cnn group action): 0.000002

# %%
equivariant_agent.policy.features_extractor
# Out:
# SmallKernelC4EquivariantCNN(
#   (equivariant_model): SequentialModule(
#     (0): SequentialModule(
#       (0): R2Conv([C4_on_R2[(None, 4)]: {irrep_0 (x3)}(3)], [C4_on_R2[(None, 4)]: {regular (x32)}(128)], kernel_size=3, stride=1, padding=1)
#       (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x32)}(128)])
#       (2): PointwiseMaxPool2D()
#     )
#     (1): SequentialModule(
#       (0): R2Conv([C4_on_R2[(None, 4)]: {regular (x32)}(128)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1)
#       (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#       (2): PointwiseMaxPool2D()
#     )
#     (2): SequentialModule(
#       (0): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1)
#       (1): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#     )
#   )
#   (group_pool): GroupPooling([C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#   (fc): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=64, out_features=256, bias=True)
#     (2): ReLU()
#   )
# )

# %% [markdown]
# # Generalization Finetuning

# %%
# %load_ext tensorboard
# %tensorboard --logdir {TENSORBOARD_LOG_DIR}
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 15227), started 1:52:40 ago. (Use '!kill 15227' to kill it.)
#       <iframe id="tensorboard-frame-4164d8399f767c45" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4164d8399f767c45");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
GEN_TIMESTEPS = 2e5
test_wrapper = Rotate180Wrapper#RandomRotateWrapper
test_degree = '180'
# test_180_270_wrapper_kwargs = {'full_obs': SEE_FULL_OBS, 'subset': [2,3]}
test_wrapper_kwargs = base_wrapper_kwargs#test_180_270_wrapper_kwargs
rot_test_std_vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED,
                               wrapper_class=test_wrapper,
                               wrapper_kwargs=test_wrapper_kwargs,
                               monitor_dir=f'./logs/rot_{test_degree}/std')
rot_test_eq_vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED,
                               wrapper_class=test_wrapper,
                               wrapper_kwargs=test_wrapper_kwargs,
                               monitor_dir=f'./logs/rot_{test_degree}/eq')
rot_test_aug_vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED,
                               wrapper_class=test_wrapper,
                               wrapper_kwargs=test_wrapper_kwargs,
                               monitor_dir=f'./logs/rot_{test_degree}/aug')
rot_test_aug_eq_vec_env = make_vec_env(ENV_NAME, n_envs=NUM_ENVS, seed=SEED,
                               wrapper_class=test_wrapper,
                               wrapper_kwargs=test_wrapper_kwargs,
                               monitor_dir=f'./logs/rot_{test_degree}/aug_eq')

# %%
new_standard_agent = make_ppo_agent(
    rot_test_std_vec_env, 
    use_equivariant_cnn=False,
    seed=SEED,
    config=standard_config,
    load='model_checkpoints/full/9x9_standard_agent_10m',
    tensorboard_log=TENSORBOARD_LOG_DIR + f"{test_degree}_standard"
)
print(f"Training standard CNN PPO for {GEN_TIMESTEPS} timesteps...")
new_standard_agent.learn(total_timesteps=int(GEN_TIMESTEPS), tb_log_name=f"{test_degree}_standard_run")
print("Standard CNN training completed!")
# Out:
# Loading model from model_checkpoints/full/9x9_standard_agent_10m
# Wrapping the env in a VecTransposeImage.
# Training standard CNN PPO for 200000.0 timesteps...
# Logging to ./tensorboard_logs/180_270_standard/180_270_standard_run_1
# -----------------------------
# | time/              |      |
# |    fps             | 3619 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 99.3      |
# |    ep_rew_mean          | 0.00903   |
# | time/                   |           |
# |    fps                  | 1722      |
# |    iterations           | 2         |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 2.4745262 |
# |    clip_fraction        | 0.187     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.261    |
# |    explained_variance   | 0.94      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.019    |
# |    n_updates            | 312       |
# |    policy_gradient_loss | -0.00201  |
# |    value_loss           | 0.0764    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.1        |
# |    ep_rew_mean          | 0.0441      |
# | time/                   |             |
# |    fps                  | 1446        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.046381973 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.444      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0718      |
# |    n_updates            | 316         |
# |    policy_gradient_loss | 0.00765     |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.9        |
# |    ep_rew_mean          | 0.0234      |
# | time/                   |             |
# |    fps                  | 1456        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.034633975 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.334      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00931    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00531     |
# |    value_loss           | 0.0729      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.1        |
# |    ep_rew_mean          | 0.021       |
# | time/                   |             |
# |    fps                  | 1465        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012588012 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0192      |
# |    n_updates            | 324         |
# |    policy_gradient_loss | -0.00402    |
# |    value_loss           | 0.0479      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.2        |
# |    ep_rew_mean          | 0.0202      |
# | time/                   |             |
# |    fps                  | 1455        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012061788 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0192     |
# |    n_updates            | 328         |
# |    policy_gradient_loss | -0.000717   |
# |    value_loss           | 0.0308      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.5        |
# |    ep_rew_mean          | 0.0276      |
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013232753 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.349      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0052      |
# |    n_updates            | 332         |
# |    policy_gradient_loss | 0.00419     |
# |    value_loss           | 0.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.6        |
# |    ep_rew_mean          | 0.0163      |
# | time/                   |             |
# |    fps                  | 1423        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011651924 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.319      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00257     |
# |    n_updates            | 336         |
# |    policy_gradient_loss | -0.000911   |
# |    value_loss           | 0.0314      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98          |
# |    ep_rew_mean          | 0.0241      |
# | time/                   |             |
# |    fps                  | 1439        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.020620514 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.309      |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00363     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00114     |
# |    value_loss           | 0.0224      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.4        |
# |    ep_rew_mean          | 0.0206      |
# | time/                   |             |
# |    fps                  | 1424        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010638246 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00444    |
# |    n_updates            | 344         |
# |    policy_gradient_loss | -0.0039     |
# |    value_loss           | 0.022       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.5         |
# |    ep_rew_mean          | 0.0189       |
# | time/                   |              |
# |    fps                  | 1444         |
# |    iterations           | 11           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0112489555 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00172     |
# |    n_updates            | 348          |
# |    policy_gradient_loss | -0.00448     |
# |    value_loss           | 0.00949      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.8        |
# |    ep_rew_mean          | 0.016       |
# | time/                   |             |
# |    fps                  | 1462        |
# |    iterations           | 12          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013935895 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.239      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00239    |
# |    n_updates            | 352         |
# |    policy_gradient_loss | -0.00712    |
# |    value_loss           | 0.00842     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.8        |
# |    ep_rew_mean          | 0.0147      |
# | time/                   |             |
# |    fps                  | 1468        |
# |    iterations           | 13          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010903326 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00433    |
# |    n_updates            | 356         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 0.00962     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.3        |
# |    ep_rew_mean          | 0.00957     |
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 14          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004875157 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.349      |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 0.00564     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.8        |
# |    ep_rew_mean          | 0.0146      |
# | time/                   |             |
# |    fps                  | 1474        |
# |    iterations           | 15          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005397984 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.274      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.014      |
# |    n_updates            | 364         |
# |    policy_gradient_loss | -0.00199    |
# |    value_loss           | 0.00755     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.5        |
# |    ep_rew_mean          | 0.0199      |
# | time/                   |             |
# |    fps                  | 1487        |
# |    iterations           | 16          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014577112 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.356      |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0196     |
# |    n_updates            | 368         |
# |    policy_gradient_loss | -0.000819   |
# |    value_loss           | 0.00528     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | 0.0142      |
# | time/                   |             |
# |    fps                  | 1497        |
# |    iterations           | 17          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006497028 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.345      |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0214     |
# |    n_updates            | 372         |
# |    policy_gradient_loss | -0.00502    |
# |    value_loss           | 0.00373     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | 0.0142      |
# | time/                   |             |
# |    fps                  | 1479        |
# |    iterations           | 18          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009377646 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.368      |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 376         |
# |    policy_gradient_loss | -0.00839    |
# |    value_loss           | 0.00223     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.2        |
# |    ep_rew_mean          | 0.0104      |
# | time/                   |             |
# |    fps                  | 1485        |
# |    iterations           | 19          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004927149 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.365      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.013      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.6         |
# |    ep_rew_mean          | 0.00524      |
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 20           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0073183984 |
# |    clip_fraction        | 0.0771       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | 0.592        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0135      |
# |    n_updates            | 384          |
# |    policy_gradient_loss | -0.00432     |
# |    value_loss           | 0.00278      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | 0.0108      |
# | time/                   |             |
# |    fps                  | 1492        |
# |    iterations           | 21          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009183746 |
# |    clip_fraction        | 0.0726      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0237     |
# |    n_updates            | 388         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 0.0027      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.7        |
# |    ep_rew_mean          | 0.0269      |
# | time/                   |             |
# |    fps                  | 1494        |
# |    iterations           | 22          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011857053 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0294     |
# |    n_updates            | 392         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00233     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.1        |
# |    ep_rew_mean          | 0.0327      |
# | time/                   |             |
# |    fps                  | 1500        |
# |    iterations           | 23          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012380895 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | -0.0725     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00674     |
# |    n_updates            | 396         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 0.00208     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.5        |
# |    ep_rew_mean          | 0.0394      |
# | time/                   |             |
# |    fps                  | 1506        |
# |    iterations           | 24          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006614756 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.5        |
# |    ep_rew_mean          | 0.0511      |
# | time/                   |             |
# |    fps                  | 1509        |
# |    iterations           | 25          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.015563054 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00827    |
# |    n_updates            | 404         |
# |    policy_gradient_loss | -0.00599    |
# |    value_loss           | 0.00181     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97          |
# |    ep_rew_mean          | 0.0348      |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 26          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013637272 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0168     |
# |    n_updates            | 408         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.3        |
# |    ep_rew_mean          | 0.0335      |
# | time/                   |             |
# |    fps                  | 1519        |
# |    iterations           | 27          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009857198 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00319     |
# |    n_updates            | 412         |
# |    policy_gradient_loss | -0.000946   |
# |    value_loss           | 0.000868    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.8        |
# |    ep_rew_mean          | 0.0408      |
# | time/                   |             |
# |    fps                  | 1519        |
# |    iterations           | 28          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016056474 |
# |    clip_fraction        | 0.0986      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 416         |
# |    policy_gradient_loss | -0.000462   |
# |    value_loss           | 0.000874    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97           |
# |    ep_rew_mean          | 0.039        |
# | time/                   |              |
# |    fps                  | 1523         |
# |    iterations           | 29           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0084216315 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | -0.00812     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.013       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 0.00138      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98          |
# |    ep_rew_mean          | 0.0273      |
# | time/                   |             |
# |    fps                  | 1524        |
# |    iterations           | 30          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010388112 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.424      |
# |    explained_variance   | 0.0549      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0259     |
# |    n_updates            | 424         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96          |
# |    ep_rew_mean          | 0.0492      |
# | time/                   |             |
# |    fps                  | 1527        |
# |    iterations           | 31          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012046922 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 0.0736      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 428         |
# |    policy_gradient_loss | -0.00955    |
# |    value_loss           | 0.000801    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96          |
# |    ep_rew_mean          | 0.049       |
# | time/                   |             |
# |    fps                  | 1529        |
# |    iterations           | 32          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.015852509 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.436      |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00648    |
# |    n_updates            | 432         |
# |    policy_gradient_loss | 0.000267    |
# |    value_loss           | 0.00275     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.3        |
# |    ep_rew_mean          | 0.0552      |
# | time/                   |             |
# |    fps                  | 1525        |
# |    iterations           | 33          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009510354 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 436         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 92.5       |
# |    ep_rew_mean          | 0.0862     |
# | time/                   |            |
# |    fps                  | 1524       |
# |    iterations           | 34         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01829001 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.436     |
# |    explained_variance   | 0.318      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0135    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00261    |
# |    value_loss           | 0.00208    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.5        |
# |    ep_rew_mean          | 0.0862      |
# | time/                   |             |
# |    fps                  | 1528        |
# |    iterations           | 35          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.020659816 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.454      |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00462     |
# |    n_updates            | 444         |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 0.00443     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90.2       |
# |    ep_rew_mean          | 0.113      |
# | time/                   |            |
# |    fps                  | 1530       |
# |    iterations           | 36         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01212302 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.504     |
# |    explained_variance   | 0.25       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000111  |
# |    n_updates            | 448        |
# |    policy_gradient_loss | -0.00131   |
# |    value_loss           | 0.00188    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.2        |
# |    ep_rew_mean          | 0.133       |
# | time/                   |             |
# |    fps                  | 1530        |
# |    iterations           | 37          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014887892 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0193     |
# |    n_updates            | 452         |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 0.00331     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.6        |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 1529        |
# |    iterations           | 38          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013231894 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.014      |
# |    n_updates            | 456         |
# |    policy_gradient_loss | -0.00898    |
# |    value_loss           | 0.00431     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.1        |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 1528        |
# |    iterations           | 39          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.013442602 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 0.00414     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.2        |
# |    ep_rew_mean          | 0.168       |
# | time/                   |             |
# |    fps                  | 1529        |
# |    iterations           | 40          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.023953423 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0291     |
# |    n_updates            | 464         |
# |    policy_gradient_loss | -0.000202   |
# |    value_loss           | 0.00365     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.4        |
# |    ep_rew_mean          | 0.157       |
# | time/                   |             |
# |    fps                  | 1526        |
# |    iterations           | 41          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.017805558 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00738     |
# |    n_updates            | 468         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 0.00609     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.7        |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 1528        |
# |    iterations           | 42          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.012470862 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0117     |
# |    n_updates            | 472         |
# |    policy_gradient_loss | -0.00879    |
# |    value_loss           | 0.0035      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.1        |
# |    ep_rew_mean          | 0.19        |
# | time/                   |             |
# |    fps                  | 1519        |
# |    iterations           | 43          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.019338053 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.48       |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00933    |
# |    n_updates            | 476         |
# |    policy_gradient_loss | -0.00533    |
# |    value_loss           | 0.00339     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.7        |
# |    ep_rew_mean          | 0.193       |
# | time/                   |             |
# |    fps                  | 1520        |
# |    iterations           | 44          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.029784452 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.486      |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 0.0066      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.2        |
# |    ep_rew_mean          | 0.175       |
# | time/                   |             |
# |    fps                  | 1512        |
# |    iterations           | 45          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011312611 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0105     |
# |    n_updates            | 484         |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 0.0042      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.2        |
# |    ep_rew_mean          | 0.186       |
# | time/                   |             |
# |    fps                  | 1500        |
# |    iterations           | 46          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.010041207 |
# |    clip_fraction        | 0.0988      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.014      |
# |    n_updates            | 488         |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 0.00336     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 84.4       |
# |    ep_rew_mean          | 0.172      |
# | time/                   |            |
# |    fps                  | 1494       |
# |    iterations           | 47         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.02302704 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.49      |
# |    explained_variance   | 0.553      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0131    |
# |    n_updates            | 492        |
# |    policy_gradient_loss | -0.0023    |
# |    value_loss           | 0.00375    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.7        |
# |    ep_rew_mean          | 0.171       |
# | time/                   |             |
# |    fps                  | 1490        |
# |    iterations           | 48          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009590038 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00962    |
# |    n_updates            | 496         |
# |    policy_gradient_loss | -0.00633    |
# |    value_loss           | 0.0048      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86           |
# |    ep_rew_mean          | 0.16         |
# | time/                   |              |
# |    fps                  | 1487         |
# |    iterations           | 49           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0131686535 |
# |    clip_fraction        | 0.0837       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0244      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00579     |
# |    value_loss           | 0.00298      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 0.173       |
# | time/                   |             |
# |    fps                  | 1476        |
# |    iterations           | 50          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.017530465 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0325     |
# |    n_updates            | 504         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00285     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.7        |
# |    ep_rew_mean          | 0.198       |
# | time/                   |             |
# |    fps                  | 1468        |
# |    iterations           | 51          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.018586658 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.472       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00568    |
# |    n_updates            | 508         |
# |    policy_gradient_loss | -0.0069     |
# |    value_loss           | 0.00296     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.8        |
# |    ep_rew_mean          | 0.186       |
# | time/                   |             |
# |    fps                  | 1463        |
# |    iterations           | 52          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.025771882 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.438      |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0159     |
# |    n_updates            | 512         |
# |    policy_gradient_loss | -0.00791    |
# |    value_loss           | 0.00647     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.5       |
# |    ep_rew_mean          | 0.214      |
# | time/                   |            |
# |    fps                  | 1455       |
# |    iterations           | 53         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.02082784 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.445     |
# |    explained_variance   | 0.507      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0361    |
# |    n_updates            | 516        |
# |    policy_gradient_loss | -0.00785   |
# |    value_loss           | 0.00255    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83         |
# |    ep_rew_mean          | 0.196      |
# | time/                   |            |
# |    fps                  | 1442       |
# |    iterations           | 54         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01940568 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.457     |
# |    explained_variance   | 0.286      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00445    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00738   |
# |    value_loss           | 0.0032     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.2        |
# |    ep_rew_mean          | 0.171       |
# | time/                   |             |
# |    fps                  | 1436        |
# |    iterations           | 55          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.020368442 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.49       |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00987    |
# |    n_updates            | 524         |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 0.00275     |
# ...
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0136     |
# |    n_updates            | 624         |
# |    policy_gradient_loss | 1.85e-05    |
# |    value_loss           | 0.00576     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.6        |
# |    ep_rew_mean          | 0.431       |
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 81          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.027465928 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.442      |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0289     |
# |    n_updates            | 628         |
# |    policy_gradient_loss | -0.0074     |
# |    value_loss           | 0.00536     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.9        |
# |    ep_rew_mean          | 0.456       |
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 82          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.030541703 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0283     |
# |    n_updates            | 632         |
# |    policy_gradient_loss | 0.00185     |
# |    value_loss           | 0.00562     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.9        |
# |    ep_rew_mean          | 0.468       |
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 83          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.031817876 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.458      |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 636         |
# |    policy_gradient_loss | -0.00638    |
# |    value_loss           | 0.00608     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.4       |
# |    ep_rew_mean          | 0.46       |
# | time/                   |            |
# |    fps                  | 1334       |
# |    iterations           | 84         |
# |    time_elapsed         | 128        |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.03542367 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.423     |
# |    explained_variance   | 0.345      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0283    |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.00791   |
# |    value_loss           | 0.00433    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.5       |
# |    ep_rew_mean          | 0.479      |
# | time/                   |            |
# |    fps                  | 1335       |
# |    iterations           | 85         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 174080     |
# | train/                  |            |
# |    approx_kl            | 0.03841809 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.415     |
# |    explained_variance   | 0.278      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0376    |
# |    n_updates            | 644        |
# |    policy_gradient_loss | -0.00285   |
# |    value_loss           | 0.00839    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.7       |
# |    ep_rew_mean          | 0.532      |
# | time/                   |            |
# |    fps                  | 1336       |
# |    iterations           | 86         |
# |    time_elapsed         | 131        |
# |    total_timesteps      | 176128     |
# | train/                  |            |
# |    approx_kl            | 0.03124331 |
# |    clip_fraction        | 0.157      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.405     |
# |    explained_variance   | 0.347      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00184   |
# |    n_updates            | 648        |
# |    policy_gradient_loss | -0.00288   |
# |    value_loss           | 0.00745    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47          |
# |    ep_rew_mean          | 0.57        |
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 87          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.034558784 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.393      |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0047     |
# |    n_updates            | 652         |
# |    policy_gradient_loss | -2.16e-05   |
# |    value_loss           | 0.00892     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.3        |
# |    ep_rew_mean          | 0.567       |
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 88          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.037130404 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.399      |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0285     |
# |    n_updates            | 656         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00648     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.4       |
# |    ep_rew_mean          | 0.593      |
# | time/                   |            |
# |    fps                  | 1327       |
# |    iterations           | 89         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 182272     |
# | train/                  |            |
# |    approx_kl            | 0.03234219 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.374     |
# |    explained_variance   | 0.276      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00671   |
# |    n_updates            | 660        |
# |    policy_gradient_loss | 0.0039     |
# |    value_loss           | 0.00827    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.5        |
# |    ep_rew_mean          | 0.631       |
# | time/                   |             |
# |    fps                  | 1324        |
# |    iterations           | 90          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.042279277 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0354     |
# |    n_updates            | 664         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00723     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38.8       |
# |    ep_rew_mean          | 0.648      |
# | time/                   |            |
# |    fps                  | 1316       |
# |    iterations           | 91         |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 186368     |
# | train/                  |            |
# |    approx_kl            | 0.04636269 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.395     |
# |    explained_variance   | 0.436      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00542    |
# |    n_updates            | 668        |
# |    policy_gradient_loss | -0.00771   |
# |    value_loss           | 0.00808    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.7       |
# |    ep_rew_mean          | 0.606      |
# | time/                   |            |
# |    fps                  | 1308       |
# |    iterations           | 92         |
# |    time_elapsed         | 144        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.03799136 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.412     |
# |    explained_variance   | 0.515      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0174    |
# |    n_updates            | 672        |
# |    policy_gradient_loss | -0.00401   |
# |    value_loss           | 0.00721    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.8        |
# |    ep_rew_mean          | 0.574       |
# | time/                   |             |
# |    fps                  | 1304        |
# |    iterations           | 93          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.027080975 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.39       |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 676         |
# |    policy_gradient_loss | -0.00829    |
# |    value_loss           | 0.00702     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.5       |
# |    ep_rew_mean          | 0.544      |
# | time/                   |            |
# |    fps                  | 1300       |
# |    iterations           | 94         |
# |    time_elapsed         | 148        |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.03808341 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.421     |
# |    explained_variance   | 0.501      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0184    |
# |    n_updates            | 680        |
# |    policy_gradient_loss | 0.00767    |
# |    value_loss           | 0.00745    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.9        |
# |    ep_rew_mean          | 0.547       |
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 95          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.027290542 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0036     |
# |    n_updates            | 684         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 0.00923     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.9       |
# |    ep_rew_mean          | 0.548      |
# | time/                   |            |
# |    fps                  | 1300       |
# |    iterations           | 96         |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.04966693 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.402     |
# |    explained_variance   | 0.595      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0126    |
# |    n_updates            | 688        |
# |    policy_gradient_loss | -0.0081    |
# |    value_loss           | 0.0064     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.4        |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 1301        |
# |    iterations           | 97          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.049866833 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 692         |
# |    policy_gradient_loss | -0.00829    |
# |    value_loss           | 0.00711     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.3        |
# |    ep_rew_mean          | 0.668       |
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 98          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.036051653 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 696         |
# |    policy_gradient_loss | -0.00804    |
# |    value_loss           | 0.00992     |
# -----------------------------------------
# Standard CNN training completed!

# %%
new_eq_agent = make_ppo_agent(
    rot_test_eq_vec_env, 
    use_equivariant_cnn=True, 
    seed=1,
    config=equivariant_config,
    load='model_checkpoints/full/9x9_eq_agent_10m',
    tensorboard_log=TENSORBOARD_LOG_DIR + f"{test_degree}_eq"
)
print(f"Training Eq. CNN PPO for {GEN_TIMESTEPS} timesteps...")
new_eq_agent.learn(total_timesteps=int(GEN_TIMESTEPS), tb_log_name=f"{test_degree}_eq_run")
print("Eq. CNN training completed!")
# Out:
# Loading model from model_checkpoints/full/9x9_eq_agent_10m
# Wrapping the env in a VecTransposeImage.
# Training Eq. CNN PPO for 300000.0 timesteps...
# Logging to ./tensorboard_logs/270_eq/270_eq_run_3
# -----------------------------
# | time/              |      |
# |    fps             | 1746 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 999        |
# |    iterations           | 2          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.14937347 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.196     |
# |    explained_variance   | 0.755      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0415     |
# |    n_updates            | 312        |
# |    policy_gradient_loss | 0.0441     |
# |    value_loss           | 0.117      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 947        |
# |    iterations           | 3          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.14411376 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.213     |
# |    explained_variance   | 0.86       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0133     |
# |    n_updates            | 316        |
# |    policy_gradient_loss | 0.0518     |
# |    value_loss           | 0.0664     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 903       |
# |    iterations           | 4         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0790895 |
# |    clip_fraction        | 0.146     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.193    |
# |    explained_variance   | 0.469     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0214    |
# |    n_updates            | 320       |
# |    policy_gradient_loss | 0.0161    |
# |    value_loss           | 0.0716    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.067169234 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.226      |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0417      |
# |    n_updates            | 324         |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 0.0474      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 765        |
# |    iterations           | 6          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.03928539 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.233     |
# |    explained_variance   | 0.609      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0114     |
# |    n_updates            | 328        |
# |    policy_gradient_loss | 0.0129     |
# |    value_loss           | 0.0351     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.062973626 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0445      |
# |    n_updates            | 332         |
# |    policy_gradient_loss | 0.0174      |
# |    value_loss           | 0.0399      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 750        |
# |    iterations           | 8          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.06918373 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.249     |
# |    explained_variance   | 0.725      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.9e-05    |
# |    n_updates            | 336        |
# |    policy_gradient_loss | -0.00538   |
# |    value_loss           | 0.034      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 9           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.036165006 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00893     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0019      |
# |    value_loss           | 0.0321      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 10          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.022893507 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.297      |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 344         |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 0.0284      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.6        |
# |    ep_rew_mean          | 0.00424     |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015685346 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.334      |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0224      |
# |    n_updates            | 348         |
# |    policy_gradient_loss | 0.0017      |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.6        |
# |    ep_rew_mean          | 0.00424     |
# | time/                   |             |
# |    fps                  | 766         |
# |    iterations           | 12          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.040368587 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.362      |
# |    explained_variance   | -0.337      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0214     |
# |    n_updates            | 352         |
# |    policy_gradient_loss | -0.00637    |
# |    value_loss           | 0.0213      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.6        |
# |    ep_rew_mean          | 0.00424     |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 13          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021283336 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00201     |
# |    n_updates            | 356         |
# |    policy_gradient_loss | 0.00371     |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.6        |
# |    ep_rew_mean          | 0.00424     |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015626121 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.472       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.000313   |
# |    value_loss           | 0.00803     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.6        |
# |    ep_rew_mean          | 0.00424     |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 15          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.061755575 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0209      |
# |    n_updates            | 364         |
# |    policy_gradient_loss | 0.00924     |
# |    value_loss           | 0.00882     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 16          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.025391215 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 368         |
# |    policy_gradient_loss | -0.00818    |
# |    value_loss           | 0.0054      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 17          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016782492 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0136     |
# |    n_updates            | 372         |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 0.00404     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 18          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016357798 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 376         |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 0.00457     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | 0.00289     |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 19          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.031570442 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0451     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.0029      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | 0.00289     |
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 20          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020862188 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 384         |
# |    policy_gradient_loss | 0.00127     |
# |    value_loss           | 0.0039      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | 0.00289     |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 21          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.020824065 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0161     |
# |    n_updates            | 388         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | 0.00289     |
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 22          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021694388 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 392         |
# |    policy_gradient_loss | -0.00633    |
# |    value_loss           | 0.00161     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | 0.00289     |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 23          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.016951561 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.019      |
# |    n_updates            | 396         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 0.00159     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 24          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025875013 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00767    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.000672   |
# |    value_loss           | 0.00126     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 780         |
# |    iterations           | 25          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.015164137 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 404         |
# |    policy_gradient_loss | -0.000604   |
# |    value_loss           | 0.00106     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 26          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.025528323 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 408         |
# |    policy_gradient_loss | 0.00139     |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 27          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.019484065 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 412         |
# |    policy_gradient_loss | -0.00508    |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 765        |
# |    iterations           | 28         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01748228 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.594     |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0154    |
# |    n_updates            | 416        |
# |    policy_gradient_loss | -0.00516   |
# |    value_loss           | 0.000817   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 29          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.021629734 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00234     |
# |    value_loss           | 0.000878    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 30          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.024731629 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00341    |
# |    n_updates            | 424         |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 0.000726    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 31          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.027110465 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.019      |
# |    n_updates            | 428         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 0.0007      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.00109     |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 32          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.020180795 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 432         |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 0.000774    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.00109     |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 33          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016809855 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 436         |
# |    policy_gradient_loss | -0.00731    |
# |    value_loss           | 0.000437    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.5        |
# |    ep_rew_mean          | 0.00695     |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 34          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022157501 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0173     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00799    |
# |    value_loss           | 0.000379    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.8        |
# |    ep_rew_mean          | 0.0137      |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 35          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.025998404 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | -0.659      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0308     |
# |    n_updates            | 444         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 0.00131     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.5        |
# |    ep_rew_mean          | 0.0165      |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 36          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.021936495 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.741      |
# |    explained_variance   | -0.0877     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 448         |
# |    policy_gradient_loss | -0.00221    |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.5        |
# |    ep_rew_mean          | 0.0272      |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 37          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.015284645 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | -0.117      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0359     |
# |    n_updates            | 452         |
# |    policy_gradient_loss | -0.00643    |
# |    value_loss           | 0.000507    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.9        |
# |    ep_rew_mean          | 0.0366      |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 38          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.024003472 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.716      |
# |    explained_variance   | 0.0414      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 456         |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 0.00167     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.4        |
# |    ep_rew_mean          | 0.044       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 39          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.021862626 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000791   |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -4e-05      |
# |    value_loss           | 0.000501    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.2        |
# |    ep_rew_mean          | 0.08        |
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 40          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.027440965 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 464         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.6       |
# |    ep_rew_mean          | 0.123      |
# | time/                   |            |
# |    fps                  | 725        |
# |    iterations           | 41         |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02402237 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.761     |
# |    explained_variance   | 0.144      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00104   |
# |    n_updates            | 468        |
# |    policy_gradient_loss | -0.00488   |
# |    value_loss           | 0.00504    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.2        |
# |    ep_rew_mean          | 0.151       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 42          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.024675906 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00721    |
# |    n_updates            | 472         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.00547     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.7        |
# |    ep_rew_mean          | 0.188       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 43          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.015367277 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00978    |
# |    n_updates            | 476         |
# |    policy_gradient_loss | 0.0048      |
# |    value_loss           | 0.00364     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.5        |
# |    ep_rew_mean          | 0.202       |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 44          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018125206 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0233     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.000219   |
# |    value_loss           | 0.00639     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 80.3       |
# |    ep_rew_mean          | 0.225      |
# | time/                   |            |
# |    fps                  | 719        |
# |    iterations           | 45         |
# |    time_elapsed         | 128        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.03615279 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.755     |
# |    explained_variance   | 0.524      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0133    |
# |    n_updates            | 484        |
# |    policy_gradient_loss | -0.0037    |
# |    value_loss           | 0.00434    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.8        |
# |    ep_rew_mean          | 0.23        |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 46          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.028537039 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.029      |
# |    n_updates            | 488         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00418     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.5        |
# |    ep_rew_mean          | 0.224       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 47          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.020429397 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 492         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 0.004       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 77.3      |
# |    ep_rew_mean          | 0.259     |
# | time/                   |           |
# |    fps                  | 700       |
# |    iterations           | 48        |
# |    time_elapsed         | 140       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0189539 |
# |    clip_fraction        | 0.175     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.736    |
# |    explained_variance   | 0.677     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00503  |
# |    n_updates            | 496       |
# |    policy_gradient_loss | -0.00392  |
# |    value_loss           | 0.0049    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.5        |
# |    ep_rew_mean          | 0.321       |
# | time/                   |             |
# |    fps                  | 694         |
# |    iterations           | 49          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.020306725 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00957    |
# |    value_loss           | 0.00673     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.8        |
# |    ep_rew_mean          | 0.399       |
# | time/                   |             |
# |    fps                  | 694         |
# |    iterations           | 50          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.023130773 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0279      |
# |    n_updates            | 504         |
# |    policy_gradient_loss | -0.00917    |
# |    value_loss           | 0.00998     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.5        |
# |    ep_rew_mean          | 0.439       |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 51          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.019733258 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 508         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 0.00781     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59          |
# |    ep_rew_mean          | 0.443       |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 52          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.032069035 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 512         |
# |    policy_gradient_loss | -0.00855    |
# |    value_loss           | 0.0067      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.9        |
# |    ep_rew_mean          | 0.423       |
# | time/                   |             |
# |    fps                  | 686         |
# |    iterations           | 53          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.017499646 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 516         |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 0.00612     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.7        |
# |    ep_rew_mean          | 0.455       |
# | time/                   |             |
# |    fps                  | 687         |
# |    iterations           | 54          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.017230414 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00455    |
# |    value_loss           | 0.0055      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.7        |
# |    ep_rew_mean          | 0.526       |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 55          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.025440706 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0271     |
# |    n_updates            | 524         |
# |    policy_gradient_loss | -0.00701    |
# |    value_loss           | 0.00691     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.3        |
# |    ep_rew_mean          | 0.567       |
# ...
# |    loss                 | -0.0297     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.0138      |
# |    value_loss           | 0.00163     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.4        |
# |    ep_rew_mean          | 0.852       |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 130         |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.028562006 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.146      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -5.5e-05    |
# |    n_updates            | 824         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 0.00269     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.5        |
# |    ep_rew_mean          | 0.834       |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 131         |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 268288      |
# | train/                  |             |
# |    approx_kl            | 0.043685652 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0761      |
# |    n_updates            | 828         |
# |    policy_gradient_loss | -0.000355   |
# |    value_loss           | 0.00123     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.4       |
# |    ep_rew_mean          | 0.816      |
# | time/                   |            |
# |    fps                  | 683        |
# |    iterations           | 132        |
# |    time_elapsed         | 395        |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.05836109 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.223     |
# |    explained_variance   | 0.431      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00709    |
# |    n_updates            | 832        |
# |    policy_gradient_loss | 0.00306    |
# |    value_loss           | 0.00256    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.9        |
# |    ep_rew_mean          | 0.848       |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 133         |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.038855705 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.145      |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0033      |
# |    n_updates            | 836         |
# |    policy_gradient_loss | 0.0149      |
# |    value_loss           | 0.00399     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.9        |
# |    ep_rew_mean          | 0.839       |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 134         |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.052444864 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.16       |
# |    explained_variance   | 0.48        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.0122      |
# |    value_loss           | 0.00243     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.1        |
# |    ep_rew_mean          | 0.836       |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 135         |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.033541746 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.157      |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 844         |
# |    policy_gradient_loss | 0.00156     |
# |    value_loss           | 0.00333     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.1        |
# |    ep_rew_mean          | 0.837       |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 136         |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.022942726 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.131      |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0271     |
# |    n_updates            | 848         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 0.00305     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26.6       |
# |    ep_rew_mean          | 0.753      |
# | time/                   |            |
# |    fps                  | 682        |
# |    iterations           | 137        |
# |    time_elapsed         | 410        |
# |    total_timesteps      | 280576     |
# | train/                  |            |
# |    approx_kl            | 0.06917362 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.247     |
# |    explained_variance   | 0.599      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0188     |
# |    n_updates            | 852        |
# |    policy_gradient_loss | 0.0215     |
# |    value_loss           | 0.0067     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | 0.767       |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 138         |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.100920305 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.342      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0523     |
# |    n_updates            | 856         |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 0.0076      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.5        |
# |    ep_rew_mean          | 0.832       |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 139         |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.032919653 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.227      |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00769    |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.8        |
# |    ep_rew_mean          | 0.82        |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 140         |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.022180874 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.155      |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 864         |
# |    policy_gradient_loss | 0.000937    |
# |    value_loss           | 0.00312     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.2        |
# |    ep_rew_mean          | 0.826       |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 141         |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.038594715 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0286     |
# |    n_updates            | 868         |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 0.00321     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | 0.846       |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 142         |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.045974437 |
# |    clip_fraction        | 0.0706      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.132      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.021      |
# |    n_updates            | 872         |
# |    policy_gradient_loss | -0.009      |
# |    value_loss           | 0.00422     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.7       |
# |    ep_rew_mean          | 0.84       |
# | time/                   |            |
# |    fps                  | 681        |
# |    iterations           | 143        |
# |    time_elapsed         | 429        |
# |    total_timesteps      | 292864     |
# | train/                  |            |
# |    approx_kl            | 0.06509442 |
# |    clip_fraction        | 0.0853     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0947    |
# |    explained_variance   | 0.385      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0392     |
# |    n_updates            | 876        |
# |    policy_gradient_loss | 0.00333    |
# |    value_loss           | 0.00208    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | 0.791       |
# | time/                   |             |
# |    fps                  | 680         |
# |    iterations           | 144         |
# |    time_elapsed         | 433         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.027717654 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.246      |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0197     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 0.00413     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 16.6      |
# |    ep_rew_mean          | 0.851     |
# | time/                   |           |
# |    fps                  | 680       |
# |    iterations           | 145       |
# |    time_elapsed         | 436       |
# |    total_timesteps      | 296960    |
# | train/                  |           |
# |    approx_kl            | 0.0397728 |
# |    clip_fraction        | 0.0914    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.237    |
# |    explained_variance   | 0.835     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0275   |
# |    n_updates            | 884       |
# |    policy_gradient_loss | -0.00224  |
# |    value_loss           | 0.00355   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 17.1      |
# |    ep_rew_mean          | 0.846     |
# | time/                   |           |
# |    fps                  | 680       |
# |    iterations           | 146       |
# |    time_elapsed         | 439       |
# |    total_timesteps      | 299008    |
# | train/                  |           |
# |    approx_kl            | 0.0323558 |
# |    clip_fraction        | 0.0521    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0948   |
# |    explained_variance   | 0.469     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00396  |
# |    n_updates            | 888       |
# |    policy_gradient_loss | -0.00205  |
# |    value_loss           | 0.00251   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.6        |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 679         |
# |    iterations           | 147         |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.035755474 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.107      |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0293      |
# |    n_updates            | 892         |
# |    policy_gradient_loss | 0.00617     |
# |    value_loss           | 0.00148     |
# -----------------------------------------
# Eq. CNN training completed!

# %%
new_aug_agent = make_ppo_agent(
    rot_test_aug_vec_env, 
    use_equivariant_cnn=False, 
    seed=SEED,
    config=standard_config,
    load='model_checkpoints/full/9x9_aug_agent_10m',
    tensorboard_log=TENSORBOARD_LOG_DIR + f"{test_degree}_aug"
)
print(f"Training aug CNN PPO for {GEN_TIMESTEPS} timesteps...")
new_aug_agent.learn(total_timesteps=int(GEN_TIMESTEPS), tb_log_name=f"{test_degree}_aug_run")
print("Aug CNN training completed!")
# Out:
# Loading model from model_checkpoints/full/9x9_aug_agent_10m
# Wrapping the env in a VecTransposeImage.
# Training aug CNN PPO for 300000.0 timesteps...
# Logging to ./tensorboard_logs/270_aug/270_aug_run_1
# -----------------------------
# | time/              |      |
# |    fps             | 3092 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 1639      |
# |    iterations           | 2         |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0842725 |
# |    clip_fraction        | 0.167     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.143    |
# |    explained_variance   | 0.428     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0761    |
# |    n_updates            | 312       |
# |    policy_gradient_loss | 0.0384    |
# |    value_loss           | 0.245     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 1495       |
# |    iterations           | 3          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01345944 |
# |    clip_fraction        | 0.0688     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.154     |
# |    explained_variance   | 0.659      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0331     |
# |    n_updates            | 316        |
# |    policy_gradient_loss | -0.00104   |
# |    value_loss           | 0.13       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1422        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.031186327 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.118      |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00278     |
# |    value_loss           | 0.128       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 1350      |
# |    iterations           | 5         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0675239 |
# |    clip_fraction        | 0.126     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.205    |
# |    explained_variance   | 0.473     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0288    |
# |    n_updates            | 324       |
# |    policy_gradient_loss | 0.0084    |
# |    value_loss           | 0.106     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 97.8       |
# |    ep_rew_mean          | 0.0235     |
# | time/                   |            |
# |    fps                  | 1283       |
# |    iterations           | 6          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.08333414 |
# |    clip_fraction        | 0.0854     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.175     |
# |    explained_variance   | 0.603      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0522     |
# |    n_updates            | 328        |
# |    policy_gradient_loss | 0.0828     |
# |    value_loss           | 0.0869     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.8        |
# |    ep_rew_mean          | 0.0235      |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.031321686 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0377      |
# |    n_updates            | 332         |
# |    policy_gradient_loss | 0.0135      |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.8        |
# |    ep_rew_mean          | 0.0235      |
# | time/                   |             |
# |    fps                  | 1230        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.038799535 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0594      |
# |    n_updates            | 336         |
# |    policy_gradient_loss | 0.00665     |
# |    value_loss           | 0.0656      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.8        |
# |    ep_rew_mean          | 0.0235      |
# | time/                   |             |
# |    fps                  | 1241        |
# |    iterations           | 9           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013112357 |
# |    clip_fraction        | 0.0856      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000309   |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00567     |
# |    value_loss           | 0.0496      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.8        |
# |    ep_rew_mean          | 0.0235      |
# | time/                   |             |
# |    fps                  | 1224        |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.056130804 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00484     |
# |    n_updates            | 344         |
# |    policy_gradient_loss | 0.085       |
# |    value_loss           | 0.0446      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.7        |
# |    ep_rew_mean          | 0.00379     |
# | time/                   |             |
# |    fps                  | 1182        |
# |    iterations           | 11          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.033061877 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.279      |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0207      |
# |    n_updates            | 348         |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 0.0373      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.7        |
# |    ep_rew_mean          | 0.00379     |
# | time/                   |             |
# |    fps                  | 1177        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.033451404 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0388      |
# |    n_updates            | 352         |
# |    policy_gradient_loss | 0.00553     |
# |    value_loss           | 0.0388      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.7        |
# |    ep_rew_mean          | 0.00379     |
# | time/                   |             |
# |    fps                  | 1195        |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.022051543 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.248      |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00845    |
# |    n_updates            | 356         |
# |    policy_gradient_loss | 0.00117     |
# |    value_loss           | 0.0319      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.5        |
# |    ep_rew_mean          | 0.00614     |
# | time/                   |             |
# |    fps                  | 1208        |
# |    iterations           | 14          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017295115 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.277      |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00941    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -2.47e-05   |
# |    value_loss           | 0.0237      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.5        |
# |    ep_rew_mean          | 0.00614     |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 15          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.042545006 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.244      |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0168     |
# |    n_updates            | 364         |
# |    policy_gradient_loss | 0.00153     |
# |    value_loss           | 0.0187      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 99.8      |
# |    ep_rew_mean          | 0.00335   |
# | time/                   |           |
# |    fps                  | 1215      |
# |    iterations           | 16        |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0407508 |
# |    clip_fraction        | 0.167     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.48     |
# |    explained_variance   | 0.137     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0162   |
# |    n_updates            | 368       |
# |    policy_gradient_loss | 0.00488   |
# |    value_loss           | 0.0149    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | 0.00335     |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 17          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015691835 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 372         |
# |    policy_gradient_loss | 0.00884     |
# |    value_loss           | 0.0125      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | 0.00335     |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 18          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.019068524 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.2        |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00681     |
# |    n_updates            | 376         |
# |    policy_gradient_loss | -0.00062    |
# |    value_loss           | 0.00837     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.001       |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 19          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.016004877 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.244      |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000657    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00269     |
# |    value_loss           | 0.00569     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.001       |
# | time/                   |             |
# |    fps                  | 1237        |
# |    iterations           | 20          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015150469 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 384         |
# |    policy_gradient_loss | 0.00133     |
# |    value_loss           | 0.00531     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1247        |
# |    iterations           | 21          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012368101 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.004       |
# |    n_updates            | 388         |
# |    policy_gradient_loss | 0.00201     |
# |    value_loss           | 0.00356     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 1256       |
# |    iterations           | 22         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02092076 |
# |    clip_fraction        | 0.0603     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.198     |
# |    explained_variance   | 0.409      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0128     |
# |    n_updates            | 392        |
# |    policy_gradient_loss | 0.000352   |
# |    value_loss           | 0.00284    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 23          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008196058 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.156      |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000372   |
# |    n_updates            | 396         |
# |    policy_gradient_loss | 0.000259    |
# |    value_loss           | 0.00245     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1235        |
# |    iterations           | 24          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009167895 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.159      |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00473    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 0.00152     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1237        |
# |    iterations           | 25          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008500254 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.154      |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00764    |
# |    n_updates            | 404         |
# |    policy_gradient_loss | 0.00424     |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1245        |
# |    iterations           | 26          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007164661 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.103      |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0156     |
# |    n_updates            | 408         |
# |    policy_gradient_loss | 0.0015      |
# |    value_loss           | 0.00153     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.5       |
# |    ep_rew_mean          | 0.00723    |
# | time/                   |            |
# |    fps                  | 1249       |
# |    iterations           | 27         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01709986 |
# |    clip_fraction        | 0.0973     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.282     |
# |    explained_variance   | -0.17      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00449   |
# |    n_updates            | 412        |
# |    policy_gradient_loss | 0.00919    |
# |    value_loss           | 0.0021     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.5        |
# |    ep_rew_mean          | 0.0184      |
# | time/                   |             |
# |    fps                  | 1244        |
# |    iterations           | 28          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014983206 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.318      |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0163      |
# |    n_updates            | 416         |
# |    policy_gradient_loss | -0.000404   |
# |    value_loss           | 0.00244     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.6        |
# |    ep_rew_mean          | 0.03        |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 29          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008233944 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.232      |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0156     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.000951   |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.8        |
# |    ep_rew_mean          | 0.0521      |
# | time/                   |             |
# |    fps                  | 1228        |
# |    iterations           | 30          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012194442 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.296      |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 424         |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 0.00151     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96          |
# |    ep_rew_mean          | 0.0478      |
# | time/                   |             |
# |    fps                  | 1220        |
# |    iterations           | 31          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.017175127 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.34       |
# |    explained_variance   | 0.0814      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0035     |
# |    n_updates            | 428         |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 0.00273     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.9        |
# |    ep_rew_mean          | 0.0609      |
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 32          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011828898 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.424      |
# |    explained_variance   | 0.000631    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0157     |
# |    n_updates            | 432         |
# |    policy_gradient_loss | 0.000393    |
# |    value_loss           | 0.00124     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.7        |
# |    ep_rew_mean          | 0.0841      |
# | time/                   |             |
# |    fps                  | 1206        |
# |    iterations           | 33          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.021680042 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 0.00689     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -6.09e-05   |
# |    n_updates            | 436         |
# |    policy_gradient_loss | 0.00416     |
# |    value_loss           | 0.0029      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 92.1       |
# |    ep_rew_mean          | 0.0874     |
# | time/                   |            |
# |    fps                  | 1205       |
# |    iterations           | 34         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01353878 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.456     |
# |    explained_variance   | 0.147      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0133    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0055    |
# |    value_loss           | 0.00272    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 88.5       |
# |    ep_rew_mean          | 0.127      |
# | time/                   |            |
# |    fps                  | 1209       |
# |    iterations           | 35         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01587886 |
# |    clip_fraction        | 0.0836     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.384     |
# |    explained_variance   | 0.484      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00149   |
# |    n_updates            | 444        |
# |    policy_gradient_loss | -0.0017    |
# |    value_loss           | 0.0022     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86          |
# |    ep_rew_mean          | 0.155       |
# | time/                   |             |
# |    fps                  | 1206        |
# |    iterations           | 36          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.027761878 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 448         |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 0.00368     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.1        |
# |    ep_rew_mean          | 0.199       |
# | time/                   |             |
# |    fps                  | 1210        |
# |    iterations           | 37          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.023430908 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.566      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00259    |
# |    n_updates            | 452         |
# |    policy_gradient_loss | -0.00699    |
# |    value_loss           | 0.00319     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83          |
# |    ep_rew_mean          | 0.186       |
# | time/                   |             |
# |    fps                  | 1215        |
# |    iterations           | 38          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.022322886 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 456         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 0.00559     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.5        |
# |    ep_rew_mean          | 0.192       |
# | time/                   |             |
# |    fps                  | 1221        |
# |    iterations           | 39          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019044058 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 0.00296     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.2        |
# |    ep_rew_mean          | 0.162       |
# | time/                   |             |
# |    fps                  | 1222        |
# |    iterations           | 40          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.021989195 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.473      |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0219     |
# |    n_updates            | 464         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 0.00394     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87           |
# |    ep_rew_mean          | 0.14         |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 41           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0113133695 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.671        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0176      |
# |    n_updates            | 468          |
# |    policy_gradient_loss | 0.000299     |
# |    value_loss           | 0.00262      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.2        |
# |    ep_rew_mean          | 0.169       |
# | time/                   |             |
# |    fps                  | 1214        |
# |    iterations           | 42          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.017381847 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 472         |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 0.00322     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.9        |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 43          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016686233 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0257      |
# |    n_updates            | 476         |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 0.00456     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.2        |
# |    ep_rew_mean          | 0.194       |
# | time/                   |             |
# |    fps                  | 1219        |
# |    iterations           | 44          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.026620397 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0264     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 0.00458     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.1        |
# |    ep_rew_mean          | 0.188       |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 45          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.026736809 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0256     |
# |    n_updates            | 484         |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 0.00298     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.3       |
# |    ep_rew_mean          | 0.187      |
# | time/                   |            |
# |    fps                  | 1210       |
# |    iterations           | 46         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01993803 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.737     |
# |    explained_variance   | 0.534      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0225    |
# |    n_updates            | 488        |
# |    policy_gradient_loss | -0.00871   |
# |    value_loss           | 0.00345    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86.2       |
# |    ep_rew_mean          | 0.158      |
# | time/                   |            |
# |    fps                  | 1183       |
# |    iterations           | 47         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01637523 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.672     |
# |    explained_variance   | 0.499      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0238    |
# |    n_updates            | 492        |
# |    policy_gradient_loss | -0.00569   |
# |    value_loss           | 0.00334    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.8        |
# |    ep_rew_mean          | 0.16        |
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 48          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.014518202 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 496         |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 0.00315     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86         |
# |    ep_rew_mean          | 0.161      |
# | time/                   |            |
# |    fps                  | 1178       |
# |    iterations           | 49         |
# |    time_elapsed         | 85         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.02094185 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.662     |
# |    explained_variance   | 0.633      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0258    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.00927   |
# |    value_loss           | 0.004      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.5        |
# |    ep_rew_mean          | 0.181       |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 50          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.031119863 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.724      |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0264     |
# |    n_updates            | 504         |
# |    policy_gradient_loss | -0.00725    |
# |    value_loss           | 0.00267     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.1        |
# |    ep_rew_mean          | 0.236       |
# | time/                   |             |
# |    fps                  | 1173        |
# |    iterations           | 51          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.018406417 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.705      |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 508         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 0.00528     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75          |
# |    ep_rew_mean          | 0.279       |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 52          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.022766884 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 512         |
# |    policy_gradient_loss | -0.00909    |
# |    value_loss           | 0.0062      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.2        |
# |    ep_rew_mean          | 0.339       |
# | time/                   |             |
# |    fps                  | 1149        |
# |    iterations           | 53          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.019026533 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00894    |
# |    n_updates            | 516         |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 0.00569     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62          |
# |    ep_rew_mean          | 0.416       |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 54          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.017343473 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.694      |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00918    |
# |    value_loss           | 0.00707     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 58.1       |
# |    ep_rew_mean          | 0.458      |
# | time/                   |            |
# |    fps                  | 1146       |
# |    iterations           | 55         |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.03514836 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.633     |
# |    explained_variance   | 0.552      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0173    |
# |    n_updates            | 524        |
# |    policy_gradient_loss | -0.00689   |
# |    value_loss           | 0.0098     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.8      |
# |    ep_rew_mean          | 0.512     |
# | time/                   |           |
# |    fps                  | 1146      |
# ...
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0912     |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.7       |
# |    ep_rew_mean          | 0.84       |
# | time/                   |            |
# |    fps                  | 1007       |
# |    iterations           | 130        |
# |    time_elapsed         | 264        |
# |    total_timesteps      | 266240     |
# | train/                  |            |
# |    approx_kl            | 0.08758246 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.182     |
# |    explained_variance   | 0.657      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0205    |
# |    n_updates            | 824        |
# |    policy_gradient_loss | 0.00374    |
# |    value_loss           | 0.00213    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.1        |
# |    ep_rew_mean          | 0.836       |
# | time/                   |             |
# |    fps                  | 1005        |
# |    iterations           | 131         |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 268288      |
# | train/                  |             |
# |    approx_kl            | 0.048392784 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.155      |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 828         |
# |    policy_gradient_loss | -0.0069     |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.3       |
# |    ep_rew_mean          | 0.843      |
# | time/                   |            |
# |    fps                  | 1006       |
# |    iterations           | 132        |
# |    time_elapsed         | 268        |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.04648451 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.197     |
# |    explained_variance   | 0.423      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0284    |
# |    n_updates            | 832        |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 0.00243    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.2       |
# |    ep_rew_mean          | 0.854      |
# | time/                   |            |
# |    fps                  | 1006       |
# |    iterations           | 133        |
# |    time_elapsed         | 270        |
# |    total_timesteps      | 272384     |
# | train/                  |            |
# |    approx_kl            | 0.06074938 |
# |    clip_fraction        | 0.051      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0952    |
# |    explained_variance   | 0.444      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00575   |
# |    n_updates            | 836        |
# |    policy_gradient_loss | -0.000813  |
# |    value_loss           | 0.00256    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.9        |
# |    ep_rew_mean          | 0.828       |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 134         |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.059584178 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.141      |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0398     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.00497     |
# |    value_loss           | 0.00384     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.1       |
# |    ep_rew_mean          | 0.787      |
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 135        |
# |    time_elapsed         | 274        |
# |    total_timesteps      | 276480     |
# | train/                  |            |
# |    approx_kl            | 0.03709012 |
# |    clip_fraction        | 0.094      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.161     |
# |    explained_variance   | 0.632      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00801   |
# |    n_updates            | 844        |
# |    policy_gradient_loss | -0.00269   |
# |    value_loss           | 0.00717    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.6        |
# |    ep_rew_mean          | 0.81        |
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 136         |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.072655864 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.214      |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 848         |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 0.00572     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.1       |
# |    ep_rew_mean          | 0.855      |
# | time/                   |            |
# |    fps                  | 1011       |
# |    iterations           | 137        |
# |    time_elapsed         | 277        |
# |    total_timesteps      | 280576     |
# | train/                  |            |
# |    approx_kl            | 0.03259734 |
# |    clip_fraction        | 0.0635     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.123     |
# |    explained_variance   | 0.603      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00404   |
# |    n_updates            | 852        |
# |    policy_gradient_loss | -0.00559   |
# |    value_loss           | 0.00358    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 17.4      |
# |    ep_rew_mean          | 0.844     |
# | time/                   |           |
# |    fps                  | 1012      |
# |    iterations           | 138       |
# |    time_elapsed         | 279       |
# |    total_timesteps      | 282624    |
# | train/                  |           |
# |    approx_kl            | 0.0585852 |
# |    clip_fraction        | 0.0374    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0593   |
# |    explained_variance   | 0.591     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00659   |
# |    n_updates            | 856       |
# |    policy_gradient_loss | -0.000936 |
# |    value_loss           | 0.00163   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.5       |
# |    ep_rew_mean          | 0.785      |
# | time/                   |            |
# |    fps                  | 1014       |
# |    iterations           | 139        |
# |    time_elapsed         | 280        |
# |    total_timesteps      | 284672     |
# | train/                  |            |
# |    approx_kl            | 0.13406819 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.179     |
# |    explained_variance   | 0.542      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.033      |
# |    n_updates            | 860        |
# |    policy_gradient_loss | 0.014      |
# |    value_loss           | 0.00273    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.6       |
# |    ep_rew_mean          | 0.785      |
# | time/                   |            |
# |    fps                  | 1015       |
# |    iterations           | 140        |
# |    time_elapsed         | 282        |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.13854884 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.253     |
# |    explained_variance   | 0.352      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0171     |
# |    n_updates            | 864        |
# |    policy_gradient_loss | 0.00561    |
# |    value_loss           | 0.00674    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.2        |
# |    ep_rew_mean          | 0.816       |
# | time/                   |             |
# |    fps                  | 1017        |
# |    iterations           | 141         |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.041637696 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.177      |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00359     |
# |    n_updates            | 868         |
# |    policy_gradient_loss | 0.000839    |
# |    value_loss           | 0.00841     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 17.3      |
# |    ep_rew_mean          | 0.843     |
# | time/                   |           |
# |    fps                  | 1018      |
# |    iterations           | 142       |
# |    time_elapsed         | 285       |
# |    total_timesteps      | 290816    |
# | train/                  |           |
# |    approx_kl            | 0.0527011 |
# |    clip_fraction        | 0.107     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.174    |
# |    explained_variance   | 0.667     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0218   |
# |    n_updates            | 872       |
# |    policy_gradient_loss | -0.00737  |
# |    value_loss           | 0.00409   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.9       |
# |    ep_rew_mean          | 0.848      |
# | time/                   |            |
# |    fps                  | 1019       |
# |    iterations           | 143        |
# |    time_elapsed         | 287        |
# |    total_timesteps      | 292864     |
# | train/                  |            |
# |    approx_kl            | 0.08724808 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.152     |
# |    explained_variance   | 0.694      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0108    |
# |    n_updates            | 876        |
# |    policy_gradient_loss | -0.0154    |
# |    value_loss           | 0.00325    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.7       |
# |    ep_rew_mean          | 0.85       |
# | time/                   |            |
# |    fps                  | 1021       |
# |    iterations           | 144        |
# |    time_elapsed         | 288        |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.02697166 |
# |    clip_fraction        | 0.0414     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0836    |
# |    explained_variance   | 0.408      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00433   |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.000826  |
# |    value_loss           | 0.00375    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 17.7     |
# |    ep_rew_mean          | 0.839    |
# | time/                   |          |
# |    fps                  | 1022     |
# |    iterations           | 145      |
# |    time_elapsed         | 290      |
# |    total_timesteps      | 296960   |
# | train/                  |          |
# |    approx_kl            | 0.06366  |
# |    clip_fraction        | 0.0958   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.125   |
# |    explained_variance   | 0.482    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0116  |
# |    n_updates            | 884      |
# |    policy_gradient_loss | -0.00457 |
# |    value_loss           | 0.00298  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 0.858       |
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 146         |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.026123207 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0911     |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0408     |
# |    n_updates            | 888         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.00166     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.1       |
# |    ep_rew_mean          | 0.819      |
# | time/                   |            |
# |    fps                  | 1024       |
# |    iterations           | 147        |
# |    time_elapsed         | 293        |
# |    total_timesteps      | 301056     |
# | train/                  |            |
# |    approx_kl            | 0.23480955 |
# |    clip_fraction        | 0.0475     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0769    |
# |    explained_variance   | 0.532      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0211    |
# |    n_updates            | 892        |
# |    policy_gradient_loss | -0.00616   |
# |    value_loss           | 0.00188    |
# ----------------------------------------
# Aug CNN training completed!

# %%
new_aug_eq_agent = make_ppo_agent(
    rot_test_aug_eq_vec_env, 
    use_equivariant_cnn=True, 
    seed=SEED,
    config=equivariant_config,
    load='model_checkpoints/full/9x9_aug_eq_agent_10m',
    tensorboard_log=TENSORBOARD_LOG_DIR + f"{test_degree}_aug_eq"
)
print(f"Training Aug eq CNN PPO for {GEN_TIMESTEPS} timesteps...")
new_aug_eq_agent.learn(total_timesteps=int(GEN_TIMESTEPS), tb_log_name=f"{test_degree}_aug_eq_run")
print("Aug eq CNN training completed!")
# Out:
# Loading model from model_checkpoints/full/9x9_aug_eq_agent_10m
# Wrapping the env in a VecTransposeImage.
# Training Aug eq CNN PPO for 200000.0 timesteps...
# Logging to ./tensorboard_logs/180_aug_eq/180_aug_eq_run_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38       |
# |    ep_rew_mean     | 0.658    |
# | time/              |          |
# |    fps             | 2670     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.1       |
# |    ep_rew_mean          | 0.0206     |
# | time/                   |            |
# |    fps                  | 1158       |
# |    iterations           | 2          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.02209749 |
# |    clip_fraction        | 0.0182     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0493    |
# |    explained_variance   | 0.391      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0626     |
# |    n_updates            | 312        |
# |    policy_gradient_loss | 0.0175     |
# |    value_loss           | 0.283      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.1       |
# |    ep_rew_mean          | 0.0199     |
# | time/                   |            |
# |    fps                  | 938        |
# |    iterations           | 3          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.19741428 |
# |    clip_fraction        | 0.0946     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.118     |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0454     |
# |    n_updates            | 316        |
# |    policy_gradient_loss | 0.015      |
# |    value_loss           | 0.083      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | 0.0101      |
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011942687 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0699     |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0356      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00573     |
# |    value_loss           | 0.0788      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | 0.00685     |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019540746 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0501     |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00653     |
# |    n_updates            | 324         |
# |    policy_gradient_loss | 0.00337     |
# |    value_loss           | 0.0692      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.4       |
# |    ep_rew_mean          | 0.00678    |
# | time/                   |            |
# |    fps                  | 918        |
# |    iterations           | 6          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.05019821 |
# |    clip_fraction        | 0.0977     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.252     |
# |    explained_variance   | 0.56       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0739     |
# |    n_updates            | 328        |
# |    policy_gradient_loss | 0.00561    |
# |    value_loss           | 0.0549     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.4       |
# |    ep_rew_mean          | 0.00658    |
# | time/                   |            |
# |    fps                  | 928        |
# |    iterations           | 7          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.10042064 |
# |    clip_fraction        | 0.099      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.214     |
# |    explained_variance   | 0.678      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0094     |
# |    n_updates            | 332        |
# |    policy_gradient_loss | 0.0152     |
# |    value_loss           | 0.0721     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.7        |
# |    ep_rew_mean          | 0.0145      |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 8           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020263948 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.295      |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.019       |
# |    n_updates            | 336         |
# |    policy_gradient_loss | 0.00432     |
# |    value_loss           | 0.0677      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.7        |
# |    ep_rew_mean          | 0.0145      |
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 9           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.021847237 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | -0.153      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0236      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0171      |
# |    value_loss           | 0.0988      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.1       |
# |    ep_rew_mean          | 0.021      |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 10         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00938921 |
# |    clip_fraction        | 0.0736     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.225     |
# |    explained_variance   | 0.641      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00412    |
# |    n_updates            | 344        |
# |    policy_gradient_loss | 0.00371    |
# |    value_loss           | 0.0389     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.1       |
# |    ep_rew_mean          | 0.021      |
# | time/                   |            |
# |    fps                  | 953        |
# |    iterations           | 11         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01742153 |
# |    clip_fraction        | 0.0842     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.231     |
# |    explained_variance   | 0.579      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00291   |
# |    n_updates            | 348        |
# |    policy_gradient_loss | 0.0168     |
# |    value_loss           | 0.0332     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.1       |
# |    ep_rew_mean          | 0.021      |
# | time/                   |            |
# |    fps                  | 958        |
# |    iterations           | 12         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.15473163 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.245     |
# |    explained_variance   | 0.615      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.349      |
# |    n_updates            | 352        |
# |    policy_gradient_loss | 0.0225     |
# |    value_loss           | 0.0247     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | 0.00649     |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 13          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007968194 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.369      |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00956     |
# |    n_updates            | 356         |
# |    policy_gradient_loss | 0.00217     |
# |    value_loss           | 0.0186      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | 0.00649     |
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 14          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015154471 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00213    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 0.00947     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | 0.00749     |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 15          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013025059 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.191      |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 364         |
# |    policy_gradient_loss | 0.00181     |
# |    value_loss           | 0.0111      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.001       |
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 16          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017098842 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.228      |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0859      |
# |    n_updates            | 368         |
# |    policy_gradient_loss | 0.01        |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.001       |
# | time/                   |             |
# |    fps                  | 975         |
# |    iterations           | 17          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006998858 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.162      |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00139    |
# |    n_updates            | 372         |
# |    policy_gradient_loss | 0.00145     |
# |    value_loss           | 0.0045      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0.001       |
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 18          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010343653 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.149      |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000446   |
# |    n_updates            | 376         |
# |    policy_gradient_loss | 0.000981    |
# |    value_loss           | 0.00598     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.7        |
# |    ep_rew_mean          | 0.00615     |
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 19          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004990658 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.187      |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00503    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -4.29e-05   |
# |    value_loss           | 0.00321     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.2        |
# |    ep_rew_mean          | 0.0107      |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 20          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005431244 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.171      |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.011      |
# |    n_updates            | 384         |
# |    policy_gradient_loss | 0.00466     |
# |    value_loss           | 0.00398     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.2        |
# |    ep_rew_mean          | 0.00975     |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 21          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011363795 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.145      |
# |    explained_variance   | 0.561       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00435     |
# |    n_updates            | 388         |
# |    policy_gradient_loss | 0.00209     |
# |    value_loss           | 0.00324     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.7        |
# |    ep_rew_mean          | 0.0154      |
# | time/                   |             |
# |    fps                  | 975         |
# |    iterations           | 22          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021249004 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 392         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.7       |
# |    ep_rew_mean          | 0.0154     |
# | time/                   |            |
# |    fps                  | 973        |
# |    iterations           | 23         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02809196 |
# |    clip_fraction        | 0.0551     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.192     |
# |    explained_variance   | 0.626      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00569   |
# |    n_updates            | 396        |
# |    policy_gradient_loss | -0.00278   |
# |    value_loss           | 0.00174    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.1        |
# |    ep_rew_mean          | 0.0103      |
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 24          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.021841427 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.205      |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00491    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00156     |
# |    value_loss           | 0.0015      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.5       |
# |    ep_rew_mean          | 0.00568    |
# | time/                   |            |
# |    fps                  | 973        |
# |    iterations           | 25         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01993538 |
# |    clip_fraction        | 0.0671     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.32      |
# |    explained_variance   | 0.511      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00113    |
# |    n_updates            | 404        |
# |    policy_gradient_loss | 0.00777    |
# |    value_loss           | 0.00107    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.5       |
# |    ep_rew_mean          | 0.00568    |
# | time/                   |            |
# |    fps                  | 973        |
# |    iterations           | 26         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01761251 |
# |    clip_fraction        | 0.0801     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.276     |
# |    explained_variance   | 0.677      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0755     |
# |    n_updates            | 408        |
# |    policy_gradient_loss | 0.0146     |
# |    value_loss           | 0.00108    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 27          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013769841 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.286      |
# |    explained_variance   | 0.374       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 412         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 0.00078     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 28          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009180893 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 416         |
# |    policy_gradient_loss | -3.88e-06   |
# |    value_loss           | 0.000644    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 29          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.034101285 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.248      |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00668    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00362     |
# |    value_loss           | 0.000717    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.3        |
# |    ep_rew_mean          | 0.00739     |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 30          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.016461913 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.276      |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 424         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 0.000465    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | 0.0108      |
# | time/                   |             |
# |    fps                  | 954         |
# |    iterations           | 31          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011456473 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.244      |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00595     |
# |    n_updates            | 428         |
# |    policy_gradient_loss | -0.000476   |
# |    value_loss           | 0.001       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99          |
# |    ep_rew_mean          | 0.0108      |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 32          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012155522 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.261      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00371    |
# |    n_updates            | 432         |
# |    policy_gradient_loss | -0.000833   |
# |    value_loss           | 0.00038     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.6        |
# |    ep_rew_mean          | 0.0165      |
# | time/                   |             |
# |    fps                  | 911         |
# |    iterations           | 33          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011852538 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.386      |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 436         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 0.000263    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.6        |
# |    ep_rew_mean          | 0.0389      |
# | time/                   |             |
# |    fps                  | 911         |
# |    iterations           | 34          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004697557 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00371    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 0.000388    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.9        |
# |    ep_rew_mean          | 0.0585      |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 35          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009530723 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 0.0442      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 444         |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 0.00289     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 92         |
# |    ep_rew_mean          | 0.0918     |
# | time/                   |            |
# |    fps                  | 906        |
# |    iterations           | 36         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00914425 |
# |    clip_fraction        | 0.0795     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.477     |
# |    explained_variance   | 0.167      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00378    |
# |    n_updates            | 448        |
# |    policy_gradient_loss | -0.000624  |
# |    value_loss           | 0.00234    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.3        |
# |    ep_rew_mean          | 0.11        |
# | time/                   |             |
# |    fps                  | 903         |
# |    iterations           | 37          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009257507 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.425      |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00941    |
# |    n_updates            | 452         |
# |    policy_gradient_loss | -0.0039     |
# |    value_loss           | 0.00325     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 90.8      |
# |    ep_rew_mean          | 0.105     |
# | time/                   |           |
# |    fps                  | 900       |
# |    iterations           | 38        |
# |    time_elapsed         | 86        |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.0190894 |
# |    clip_fraction        | 0.103     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.448    |
# |    explained_variance   | 0.141     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00407  |
# |    n_updates            | 456       |
# |    policy_gradient_loss | -0.000256 |
# |    value_loss           | 0.00259   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.2        |
# |    ep_rew_mean          | 0.113       |
# | time/                   |             |
# |    fps                  | 900         |
# |    iterations           | 39          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.023258317 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.505      |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0207     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.8         |
# |    ep_rew_mean          | 0.102        |
# | time/                   |              |
# |    fps                  | 898          |
# |    iterations           | 40           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0057479143 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.419        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0168      |
# |    n_updates            | 464          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 0.00136      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.6         |
# |    ep_rew_mean          | 0.119        |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 41           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0122960135 |
# |    clip_fraction        | 0.0736       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.485       |
# |    explained_variance   | 0.364        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0152      |
# |    n_updates            | 468          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 0.00337      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89          |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 42          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019426163 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0187     |
# |    n_updates            | 472         |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 0.00296     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.4         |
# |    ep_rew_mean          | 0.118        |
# | time/                   |              |
# |    fps                  | 895          |
# |    iterations           | 43           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0112622995 |
# |    clip_fraction        | 0.0833       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.393        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00521     |
# |    n_updates            | 476          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 0.00512      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.7        |
# |    ep_rew_mean          | 0.115       |
# | time/                   |             |
# |    fps                  | 892         |
# |    iterations           | 44          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.020201366 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00934    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 0.00234     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 0.169       |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 45          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.025528308 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 484         |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 0.00412     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.5        |
# |    ep_rew_mean          | 0.196       |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 46          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.025534058 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0034     |
# |    n_updates            | 488         |
# |    policy_gradient_loss | 0.0017      |
# |    value_loss           | 0.00677     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.2        |
# |    ep_rew_mean          | 0.299       |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 47          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.026116405 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.025      |
# |    n_updates            | 492         |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 0.00747     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.5        |
# |    ep_rew_mean          | 0.375       |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 48          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.027712245 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.029      |
# |    n_updates            | 496         |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 0.00848     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.2        |
# |    ep_rew_mean          | 0.426       |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 49          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.020518279 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00263    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.7       |
# |    ep_rew_mean          | 0.472      |
# | time/                   |            |
# |    fps                  | 888        |
# |    iterations           | 50         |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.02352627 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.572     |
# |    explained_variance   | 0.463      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0316    |
# |    n_updates            | 504        |
# |    policy_gradient_loss | -0.00846   |
# |    value_loss           | 0.00835    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 53.1       |
# |    ep_rew_mean          | 0.506      |
# | time/                   |            |
# |    fps                  | 887        |
# |    iterations           | 51         |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.03442405 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.522     |
# |    explained_variance   | 0.567      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00169   |
# |    n_updates            | 508        |
# |    policy_gradient_loss | 0.000408   |
# |    value_loss           | 0.0108     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.5       |
# |    ep_rew_mean          | 0.542      |
# | time/                   |            |
# |    fps                  | 884        |
# |    iterations           | 52         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.03538539 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.536     |
# |    explained_variance   | 0.623      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0358    |
# |    n_updates            | 512        |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 0.011      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.6       |
# |    ep_rew_mean          | 0.602      |
# | time/                   |            |
# |    fps                  | 883        |
# |    iterations           | 53         |
# |    time_elapsed         | 122        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.03630051 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.536     |
# |    explained_variance   | 0.553      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0193    |
# |    n_updates            | 516        |
# |    policy_gradient_loss | -0.00518   |
# |    value_loss           | 0.013      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34         |
# |    ep_rew_mean          | 0.69       |
# | time/                   |            |
# |    fps                  | 882        |
# |    iterations           | 54         |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.02002734 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.479     |
# |    explained_variance   | 0.564      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0225    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0075    |
# |    value_loss           | 0.0116     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 0.729       |
# | time/                   |             |
# |    fps                  | 883         |
# |    iterations           | 55          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.028744793 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 524         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.3       |
# ...
# |    loss                 | -0.0187     |
# |    n_updates            | 624         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 0.00319     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.6        |
# |    ep_rew_mean          | 0.851       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 81          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.060639285 |
# |    clip_fraction        | 0.0684      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.112      |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00496    |
# |    n_updates            | 628         |
# |    policy_gradient_loss | 0.00647     |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.1        |
# |    ep_rew_mean          | 0.855       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 82          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.067296565 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.137      |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00199    |
# |    n_updates            | 632         |
# |    policy_gradient_loss | 0.00443     |
# |    value_loss           | 0.000974    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.7        |
# |    ep_rew_mean          | 0.841       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 83          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.111707225 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.113      |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0214     |
# |    n_updates            | 636         |
# |    policy_gradient_loss | 0.0927      |
# |    value_loss           | 0.00152     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.2        |
# |    ep_rew_mean          | 0.845       |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 84          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.024236187 |
# |    clip_fraction        | 0.0947      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.14       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 0.00219     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.4        |
# |    ep_rew_mean          | 0.834       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 85          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.057031475 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.144      |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 644         |
# |    policy_gradient_loss | 0.0403      |
# |    value_loss           | 0.0029      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.2       |
# |    ep_rew_mean          | 0.854      |
# | time/                   |            |
# |    fps                  | 860        |
# |    iterations           | 86         |
# |    time_elapsed         | 204        |
# |    total_timesteps      | 176128     |
# | train/                  |            |
# |    approx_kl            | 0.09923128 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.158     |
# |    explained_variance   | 0.45       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0154    |
# |    n_updates            | 648        |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 0.00335    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.1        |
# |    ep_rew_mean          | 0.855       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 87          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.017243424 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.108      |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000611   |
# |    n_updates            | 652         |
# |    policy_gradient_loss | -0.000502   |
# |    value_loss           | 0.00282     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.5       |
# |    ep_rew_mean          | 0.851      |
# | time/                   |            |
# |    fps                  | 860        |
# |    iterations           | 88         |
# |    time_elapsed         | 209        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.03950235 |
# |    clip_fraction        | 0.0677     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.112     |
# |    explained_variance   | 0.721      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0207     |
# |    n_updates            | 656        |
# |    policy_gradient_loss | -0.0048    |
# |    value_loss           | 0.00061    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 0.819       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 89          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.109925866 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.151       |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.0118      |
# |    value_loss           | 0.00109     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 0.774      |
# | time/                   |            |
# |    fps                  | 860        |
# |    iterations           | 90         |
# |    time_elapsed         | 214        |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.17320535 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.234     |
# |    explained_variance   | -0.024     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0425    |
# |    n_updates            | 664        |
# |    policy_gradient_loss | 0.00232    |
# |    value_loss           | 0.00457    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.4        |
# |    ep_rew_mean          | 0.843       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 91          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.044921197 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.202      |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00163     |
# |    n_updates            | 668         |
# |    policy_gradient_loss | 0.0105      |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 19.6       |
# |    ep_rew_mean          | 0.824      |
# | time/                   |            |
# |    fps                  | 860        |
# |    iterations           | 92         |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.04786824 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.192     |
# |    explained_variance   | 0.364      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0168    |
# |    n_updates            | 672        |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 0.00341    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.1       |
# |    ep_rew_mean          | 0.67       |
# | time/                   |            |
# |    fps                  | 861        |
# |    iterations           | 93         |
# |    time_elapsed         | 221        |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.08135961 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.286     |
# |    explained_variance   | 0.646      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00693    |
# |    n_updates            | 676        |
# |    policy_gradient_loss | -0.00733   |
# |    value_loss           | 0.00498    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.9        |
# |    ep_rew_mean          | 0.668       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 94          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.022514468 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.299      |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00251     |
# |    value_loss           | 0.00584     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.7        |
# |    ep_rew_mean          | 0.761       |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 95          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.054585066 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.252      |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0193     |
# |    n_updates            | 684         |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 0.0053      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27         |
# |    ep_rew_mean          | 0.751      |
# | time/                   |            |
# |    fps                  | 859        |
# |    iterations           | 96         |
# |    time_elapsed         | 228        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.04042551 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.338     |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0213    |
# |    n_updates            | 688        |
# |    policy_gradient_loss | -0.00893   |
# |    value_loss           | 0.00538    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.3        |
# |    ep_rew_mean          | 0.746       |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 97          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.021161249 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 692         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 0.00598     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.6       |
# |    ep_rew_mean          | 0.776      |
# | time/                   |            |
# |    fps                  | 857        |
# |    iterations           | 98         |
# |    time_elapsed         | 233        |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.03466846 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.345     |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0076    |
# |    n_updates            | 696        |
# |    policy_gradient_loss | -0.00054   |
# |    value_loss           | 0.00494    |
# ----------------------------------------
# Aug eq CNN training completed!
